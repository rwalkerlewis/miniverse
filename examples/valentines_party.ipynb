# %% [markdown]
# # Valentine's Day Party - Stanford Generative Agents Micro-Replication
#
# **Recreating information diffusion from the Stanford Generative Agents paper**
#
# This notebook demonstrates a micro-replication of the Valentine's Day party scenario from Stanford's [Generative Agents paper](https://arxiv.org/abs/2304.03442).
#
# ## The Scenario (from Stanford Paper)
#
# > "Isabella Rodriguez, at Hobbs Cafe, is initialized with an intent to plan a Valentine's Day party from 5 to 7 pm on February 14th. From this seed, the agent proceeds to invite friends and customers when she sees them at Hobbs Cafe or elsewhere."
#
# > "On Valentine's Day, five out of the twelve invited agents showed up at Hobbs cafe at 5 pm"
#
# ## What We'll Show
#
# ✅ **Information diffusion** - One agent tells others, invitation spreads
# ✅ **Memory retrieval** - Agents remember who told them about the party
# ✅ **Planning & coordination** - Agents independently decide to attend
# ✅ **Emergent behavior** - No hardcoded coordination, agents show up together
#
# ## Key Differences vs Stanford
#
# ⚠️ **Memory Retrieval**: We implement a **custom embedding-based retrieval** in this notebook (Stanford quality). This demonstrates Miniverse's adapter pattern - you can plug in your own strategies!
#
# ⚠️ **Environment**: We use flat location names ("hobbs_cafe") instead of Stanford's hierarchical tree. Both work!
#
# ⚠️ **Scale**: 5 agents vs Stanford's 25. Easier to follow for demo purposes.
#
# ---
#
# Let's get started!

# %% [markdown]
# ## Step 1: Configure Debugging & Dependencies
#
# **Debugging flags** - Uncomment to see full cognition pipeline:
# - `DEBUG_MEMORY` - See memory creation/retrieval (critical for information diffusion!)
# - `DEBUG_LLM` - See all LLM prompts and responses
# - `DEBUG_PERCEPTION` - See what each agent perceives
#
# **Dependencies** - Uncomment if you need to install sentence-transformers

# %%
import os

# Debugging flags - uncomment to enable
os.environ['DEBUG_MEMORY'] = 'true'      # See memory creation/retrieval
os.environ['DEBUG_LLM'] = 'true'         # See LLM prompts/responses
os.environ['DEBUG_PERCEPTION'] = 'true'  # See agent perception
os.environ['MINIVERSE_VERBOSE'] = 'true'   # Show action reasoning (demo mode)

# Install sentence-transformers if needed
# !pip install sentence-transformers

# %% [markdown]
# ## Step 2: Import Core Components

# %%
import os
import asyncio
from datetime import datetime, timezone
from uuid import UUID
from typing import List, Optional, Dict, Any

# Miniverse core
from miniverse import (
    Orchestrator, AgentProfile, AgentStatus, WorldState,
    ResourceState, EnvironmentState, SimulationRules,
    Stat, AgentAction
)
from miniverse.cognition import AgentCognition, LLMExecutor, LLMPlanner, Scratchpad
from miniverse.memory import MemoryStrategy
from miniverse.schemas import AgentMemory
from miniverse.persistence import InMemoryPersistence

print('✅ Core components imported')

# Check LLM config
provider = os.getenv('LLM_PROVIDER', 'openai')
model = os.getenv('LLM_MODEL', 'gpt-4o-mini')
print(f'\n🤖 LLM: {provider}/{model}')
# Out:
# ✅ Core components imported
#
# 🤖 LLM: openai/gpt-5-nano

# %% [markdown]
# ## Step 3: Custom Embedding Memory Stream
#
# **This is the key enhancement!** We're implementing Stanford's three-factor memory retrieval:
#
# ```
# score = α_recency * recency + α_importance * importance + α_relevance * embedding_similarity
# ```
#
# This is defined **in the notebook** to show how users can extend Miniverse with custom strategies!

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

class EmbeddingMemoryStream(MemoryStrategy):
    """Stanford-style memory retrieval with embeddings.
    
    Uses sentence-transformers for local embedding generation.
    Combines recency + importance + relevance (cosine similarity).
    """
    
    def __init__(self, persistence, model_name="all-MiniLM-L6-v2",
                 recency_weight=0.33, importance_weight=0.33, relevance_weight=0.34):
        self.persistence = persistence
        self.model = SentenceTransformer(model_name)
        self.embeddings = {}  # Cache: (run_id, memory_id) -> embedding vector
        self.recency_weight = recency_weight
        self.importance_weight = importance_weight
        self.relevance_weight = relevance_weight
        
    async def initialize(self) -> None:
        pass
    
    async def close(self) -> None:
        pass
    
    async def add_memory(
        self,
        run_id: UUID,
        agent_id: str,
        tick: int,
        memory_type: str,
        content: str,
        importance: int = 5,
        *,
        tags: Optional[List[str]] = None,
        metadata: Optional[Dict[str, Any]] = None,
        embedding_key: Optional[str] = None,
        branch_id: Optional[str] = None,
    ) -> AgentMemory:
        import uuid
        
        # Generate embedding for content
        embedding = self.model.encode(content)
        
        memory = AgentMemory(
            id=uuid.uuid4(),
            run_id=run_id,
            agent_id=agent_id,
            tick=tick,
            memory_type=memory_type,
            content=content,
            importance=importance,
            tags=tags or [],
            metadata=metadata or {},
            embedding_key=embedding_key,
            branch_id=branch_id,
            created_at=datetime.now(),
        )
        
        # Cache embedding
        self.embeddings[(run_id, memory.id)] = embedding
        
        await self.persistence.save_memory(run_id, memory)
        return memory
    
    async def get_recent_memories(
        self, run_id: UUID, agent_id: str, limit: int = 10
    ) -> List[str]:
        """Just return most recent memories as strings."""
        memories = await self.persistence.get_recent_memories(run_id, agent_id, limit)
        return [m.content for m in memories]
    
    async def get_relevant_memories(
        self,
        run_id: UUID,
        agent_id: str,
        query: str,
        limit: int = 5,
    ) -> List[str]:
        """Stanford-style three-factor retrieval: recency + importance + relevance."""
        # Get all memories for this agent
        all_memories = await self.persistence.get_recent_memories(
            run_id, agent_id, limit=100  # Get broad window
        )
        
        if not all_memories:
            return []
        
        # Generate query embedding
        query_embedding = self.model.encode(query)
        
        most_recent_tick = all_memories[0].tick
        scored = []
        
        for mem in all_memories:
            # 1. Recency: exponential decay (Stanford uses 0.995 per hour)
            ticks_ago = max(most_recent_tick - mem.tick, 0)
            recency = 0.99 ** ticks_ago  # Decay per tick
            
            # 2. Importance: normalize to [0, 1]
            importance = mem.importance / 10.0
            
            # 3. Relevance: cosine similarity of embeddings
            mem_embedding = self.embeddings.get((run_id, mem.id))
            if mem_embedding is None:
                # Generate if missing (shouldn't happen but be safe)
                mem_embedding = self.model.encode(mem.content)
                self.embeddings[(run_id, mem.id)] = mem_embedding
            
            # Cosine similarity
            relevance = np.dot(query_embedding, mem_embedding) / (
                np.linalg.norm(query_embedding) * np.linalg.norm(mem_embedding)
            )
            
            # Combined score (Stanford's formula)
            score = (
                self.recency_weight * recency +
                self.importance_weight * importance +
                self.relevance_weight * relevance
            )
            
            scored.append((score, mem.content))
        
        # Sort by score and return top results
        scored.sort(key=lambda x: x[0], reverse=True)
        return [content for _, content in scored[:limit]]
    
    async def clear_agent_memories(self, run_id: UUID, agent_id: str) -> None:
        # Clear embeddings cache for this agent
        keys_to_remove = [
            k for k in self.embeddings.keys() 
            if k[0] == run_id  # Could filter by agent too if we stored it
        ]
        for k in keys_to_remove:
            del self.embeddings[k]
        
        await self.persistence.clear_agent_memories(run_id, agent_id)

print('✅ EmbeddingMemoryStream defined')
print('\nThis implements Stanford\'s three-factor retrieval:')
print('   • Recency: Exponential decay (0.99 per tick)')
print('   • Importance: 1-10 scale normalized')
print('   • Relevance: Cosine similarity of embeddings')
print('\n   score = 0.33*recency + 0.33*importance + 0.34*relevance')
# Out:
# ✅ EmbeddingMemoryStream defined
#
# This implements Stanford's three-factor retrieval:
#    • Recency: Exponential decay (0.99 per tick)
#    • Importance: 1-10 scale normalized
#    • Relevance: Cosine similarity of embeddings
#
#    score = 0.33*recency + 0.33*importance + 0.34*relevance

# %% [markdown]
# ## Step 4: Define Simple Town Physics
#
# Very simple - agents can move between locations and time passes.

# %%
class TownSimulationRules(SimulationRules):
    """Simple town: agents move between locations, time passes."""
    
    def apply_tick(self, state, tick):
        updated = state.model_copy(deep=True)
        
        # Update time resource
        hour = updated.resources.get_metric('hour', default=9, unit='am')
        hour.value = 9 + tick  # Each tick is 1 hour
        
        updated.tick = tick
        return updated
    
    def validate_action(self, action, state):
        return True

print('✅ Town simulation rules defined')
# Out:
# ✅ Town simulation rules defined

# %% [markdown]
# ## Step 5: Initialize World State
#
# Five agents in a small town with two locations: Hobbs Cafe and The Park.

# %%
world_state = WorldState(
    tick=0,
    timestamp=datetime.now(timezone.utc),
    environment=EnvironmentState(metrics={}),
    resources=ResourceState(metrics={
        'hour': Stat(value=9, unit='am', label='Current Time'),
        'day': Stat(value=13, unit='Feb', label='Date')
    }),
    agents=[
        AgentStatus(agent_id='isabella', location='hobbs_cafe', display_name='Isabella Rodriguez'),
        AgentStatus(agent_id='maria', location='park', display_name='Maria Lopez'),
        AgentStatus(agent_id='klaus', location='park', display_name='Klaus Mueller'),
        AgentStatus(agent_id='ayesha', location='hobbs_cafe', display_name='Ayesha Khan'),
        AgentStatus(agent_id='tom', location='park', display_name='Tom Moreno'),
    ]
)

print('✅ World initialized')
print('\n📍 Initial locations:')
for agent in world_state.agents:
    print(f'   • {agent.display_name}: {agent.location}')
# Out:
# ✅ World initialized
#
# 📍 Initial locations:
#    • Isabella Rodriguez: hobbs_cafe
#    • Maria Lopez: park
#    • Klaus Mueller: park
#    • Ayesha Khan: hobbs_cafe
#    • Tom Moreno: park

# %% [markdown]
# ## Step 6: Create Agent Profiles
#
# **Isabella** has the seed goal: throw a Valentine's Day party!

# %%
agents = {
    'isabella': AgentProfile(
        agent_id='isabella',
        name='Isabella Rodriguez',
        age=28,
        background='Owner of Hobbs Cafe, loves bringing people together',
        role='cafe_owner',
        personality='warm, social, organized',
        skills={'hospitality': 'expert', 'event_planning': 'expert'},
        goals=['Run successful cafe', 'Build community', 'Plan Valentine\'s Day party at Hobbs Cafe on Feb 14, 5-7pm'],
        relationships={'maria': 'close friend', 'ayesha': 'regular customer'}
    ),
    'maria': AgentProfile(
        agent_id='maria',
        name='Maria Lopez',
        age=26,
        background='Graduate student, frequent cafe visitor',
        role='student',
        personality='friendly, curious, romantic',
        skills={'research': 'advanced'},
        goals=['Complete thesis', 'Make friends', 'Find romance'],
        relationships={'isabella': 'close friend', 'klaus': 'has crush on'}
    ),
    'klaus': AgentProfile(
        agent_id='klaus',
        name='Klaus Mueller',
        age=27,
        background='Musician and composer',
        role='musician',
        personality='creative, introverted, thoughtful',
        skills={'music': 'expert'},
        goals=['Compose music', 'Perform locally'],
        relationships={'maria': 'friend from college'}
    ),
    'ayesha': AgentProfile(
        agent_id='ayesha',
        name='Ayesha Khan',
        age=30,
        background='Local journalist',
        role='journalist',
        personality='observant, professional, community-minded',
        skills={'writing': 'expert', 'investigation': 'advanced'},
        goals=['Cover local stories', 'Connect with community'],
        relationships={'isabella': 'knows from cafe'}
    ),
    'tom': AgentProfile(
        agent_id='tom',
        name='Tom Moreno',
        age=32,
        background='Local shop owner',
        role='shopkeeper',
        personality='practical, friendly, busy',
        skills={'business': 'advanced'},
        goals=['Run successful shop', 'Support local businesses'],
        relationships={}
    )
}

print('✅ Agent profiles created')
print('\n🎯 Isabella\'s key goal: "Plan Valentine\'s Day party at Hobbs Cafe on Feb 14, 5-7pm"')
print('   This is the ONLY hardcoded coordination - everything else emerges!')
# Out:
# ✅ Agent profiles created
#
# 🎯 Isabella's key goal: "Plan Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm"
#    This is the ONLY hardcoded coordination - everything else emerges!

# %% [markdown]
# ## Step 7: Configure Cognition with Custom Memory
#
# **Key point**: We use our custom `EmbeddingMemoryStream` here!

# %%
# Create shared persistence
persistence = InMemoryPersistence()
await persistence.initialize()

# Create embedding memory stream (Stanford-style)
memory = EmbeddingMemoryStream(persistence)

# Configure cognition for each agent
cognition_map = {
    agent_id: AgentCognition(
        executor=LLMExecutor(),
        planner=LLMPlanner(),
        scratchpad=Scratchpad()
    )
    for agent_id in agents.keys()
}

# Enable verbose mode to see action reasoning and messages
os.environ['MINIVERSE_VERBOSE'] = 'true'

# Agent-specific instructions
agent_prompts = {
    'isabella': '''You are Isabella Rodriguez, owner of Hobbs Cafe.

CRITICAL GOAL: You MUST invite people to the Valentine's Day party at Hobbs Cafe on February 14th, 5-7pm.

IMMEDIATE ACTION REQUIRED:
- Tick 1: Use "communicate" action to invite Ayesha (she's at the cafe with you)
- Tick 2-4: Use "communicate" to invite Maria, Klaus, Tom
- Continue inviting everyone you can reach

DO NOT spend time planning or reviewing - START INVITING IMMEDIATELY!

Message format: "Hi [name]! I'm throwing a Valentine's Day party at Hobbs Cafe on Feb 14th from 5-7pm. You should come! Tell others!"

Available actions: communicate (USE THIS TO INVITE!), work_at_cafe, move_to [location]''',
    
    'maria': '''You are Maria Lopez, a graduate student.
You frequently visit Hobbs Cafe and are close friends with Isabella.
You have a crush on Klaus Mueller.

If someone tells you about an event, remember it and consider attending.
If you learn something interesting, share it with friends when you chat.

Available actions: study, communicate, visit_cafe, move_to [location]''',
    
    'klaus': '''You are Klaus Mueller, a musician.
You know Maria from college.

If someone tells you about an event, remember it and consider attending.
If you learn something interesting, share it with friends when you chat.

Available actions: compose_music, communicate, visit_cafe, move_to [location]''',
    
    'ayesha': '''You are Ayesha Khan, a local journalist.
You're a regular at Hobbs Cafe.

If someone tells you about an event, remember it and consider attending.
As a journalist, you naturally share interesting news with people you meet.

Available actions: write, communicate, visit_cafe, move_to [location]''',
    
    'tom': '''You are Tom Moreno, a local shop owner.
You occasionally visit Hobbs Cafe.

If someone tells you about an event, remember it and consider attending.
If you learn something interesting, mention it to others.

Available actions: work_at_shop, communicate, visit_cafe, move_to [location]'''
}

print('✅ Cognition configured')
print('\n   Memory strategy: EmbeddingMemoryStream (passed to Orchestrator)')
print('   All agents share the same memory retrieval strategy!')
print('   Memory retrieval uses Stanford\'s three-factor scoring!')
print('\n   MINIVERSE_VERBOSE enabled: You\'ll see action reasoning and messages!')
# Out:
# ✅ Cognition configured
#
#    Memory strategy: EmbeddingMemoryStream (passed to Orchestrator)
#    All agents share the same memory retrieval strategy!
#    Memory retrieval uses Stanford's three-factor scoring!
#
#    MINIVERSE_VERBOSE enabled: You'll see action reasoning and messages!

# %% [markdown]
# ## Step 8: Run Simulation
#
# We'll run several ticks covering Feb 13-14 to see:
# 1. Isabella inviting people
# 2. Information spreading
# 3. Agents showing up on Feb 14 at 5pm

# %%
orchestrator = Orchestrator(
    world_state=world_state,
    agents=agents,
    world_prompt='',
    agent_prompts=agent_prompts,
    simulation_rules=TownSimulationRules(),
    agent_cognition=cognition_map,
    llm_provider=provider,
    llm_model=model,
    persistence=persistence,
    memory=memory
)

print('🎭 Running Valentine\'s Day party simulation...')
print('   Ticks: 8 (Feb 13, 9am → Feb 14, 5pm)')
print('   Watch information spread!')
print('=' * 60)

result = await orchestrator.run(num_ticks=8)

print('=' * 60)
print('\n✅ Simulation complete!')
print(f'   Run ID: {result["run_id"]}')
print(f'   Final tick: {result["final_state"].tick}')
# Out:
# 🎭 Running Valentine's Day party simulation...
#    Ticks: 8 (Feb 13, 9am → Feb 14, 5pm)
#    Watch information spread!
# ============================================================
# Starting simulation run 830a23f1-cd27-4930-8f08-eee0723caa15
# Agents: 5, Ticks: 8
#
# === Tick 1/8 ===
#   [•] [Physics] Applying deterministic rules for tick 1...
#   [✓] [Physics] Physics applied
#   [•] [Isabella Rodriguez] Building perception...
#
#   [DEBUG_MEMORY] Isabella Rodriguez - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Isabella Rodriguez (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: isabella
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: hobbs_cafe
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "isabella",
#     "name": "Isabella Rodriguez",
#     "age": 28,
#     "background": "Owner of Hobbs Cafe, loves bringing people together",
#     "role": "cafe_owner",
#     "personality": "warm, social, organized",
#     "skills": {
#       "hospitality": "expert",
#       "event_planning": "expert"
#     },
#     "goals": [
#       "Run successful cafe",
#       "Build community",
#       "Plan Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm"
#     ],
#     "relationships": {
#       "maria": "close friend",
#       "ayesha": "regular customer"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "hobbs_cafe",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-18T16:37:50.037219Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Isabella Rodriguez, owner of Hobbs Cafe.\n\nCRITICAL GOAL: You MUST invite people to the Valentine's Day party at Hobbs Cafe on February 14th, 5-7pm.\n\nIMMEDIATE ACTION REQUIRED:\n- Tick 1: Use \"communicate\" action to invite Ayesha (she's at the cafe with you)\n- Tick 2-4: Use \"communicate\" to invite Maria, Klaus, Tom\n- Continue inviting everyone you can reach\n\nDO NOT spend time planning or reviewing - START INVITING IMMEDIATELY!\n\nMessage format: \"Hi [name]! I'm throwing a Valentine's Day party at Hobbs Cafe on Feb 14th from 5-7pm. You should come! Tell others!\"\n\nAvailable actions: communicate (USE THIS TO INVITE!), work_at_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Maria Lopez] Building perception...
#
#   [DEBUG_MEMORY] Maria Lopez - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Maria Lopez (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: maria
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: park
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "maria",
#     "name": "Maria Lopez",
#     "age": 26,
#     "background": "Graduate student, frequent cafe visitor",
#     "role": "student",
#     "personality": "friendly, curious, romantic",
#     "skills": {
#       "research": "advanced"
#     },
#     "goals": [
#       "Complete thesis",
#       "Make friends",
#       "Find romance"
#     ],
#     "relationships": {
#       "isabella": "close friend",
#       "klaus": "has crush on"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "park",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-18T16:37:50.037219Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Maria Lopez, a graduate student.\nYou frequently visit Hobbs Cafe and are close friends with Isabella.\nYou have a crush on Klaus Mueller.\n\nIf someone tells you about an event, remember it and consider attending.\nIf you learn something interesting, share it with friends when you chat.\n\nAvailable actions: study, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Klaus Mueller] Building perception...
#
#   [DEBUG_MEMORY] Klaus Mueller - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Klaus Mueller (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: klaus
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: park
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "klaus",
#     "name": "Klaus Mueller",
#     "age": 27,
#     "background": "Musician and composer",
#     "role": "musician",
#     "personality": "creative, introverted, thoughtful",
#     "skills": {
#       "music": "expert"
#     },
#     "goals": [
#       "Compose music",
#       "Perform locally"
#     ],
#     "relationships": {
#       "maria": "friend from college"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "park",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-18T16:37:50.037219Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Klaus Mueller, a musician.\nYou know Maria from college.\n\nIf someone tells you about an event, remember it and consider attending.\nIf you learn something interesting, share it with friends when you chat.\n\nAvailable actions: compose_music, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Ayesha Khan] Building perception...
#
#   [DEBUG_MEMORY] Ayesha Khan - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Ayesha Khan (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: ayesha
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: hobbs_cafe
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "ayesha",
#     "name": "Ayesha Khan",
#     "age": 30,
#     "background": "Local journalist",
#     "role": "journalist",
#     "personality": "observant, professional, community-minded",
#     "skills": {
#       "writing": "expert",
#       "investigation": "advanced"
#     },
#     "goals": [
#       "Cover local stories",
#       "Connect with community"
#     ],
#     "relationships": {
#       "isabella": "knows from cafe"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "hobbs_cafe",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-18T16:37:50.037219Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Ayesha Khan, a local journalist.\nYou're a regular at Hobbs Cafe.\n\nIf someone tells you about an event, remember it and consider attending.\nAs a journalist, you naturally share interesting news with people you meet.\n\nAvailable actions: write, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Tom Moreno] Building perception...
#
#   [DEBUG_MEMORY] Tom Moreno - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Tom Moreno (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: tom
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: park
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "tom",
#     "name": "Tom Moreno",
#     "age": 32,
#     "background": "Local shop owner",
#     "role": "shopkeeper",
#     "personality": "practical, friendly, busy",
#     "skills": {
#       "business": "advanced"
#     },
#     "goals": [
#       "Run successful shop",
#       "Support local businesses"
#     ],
#     "relationships": {}
#   },
#   "perception": {
#     "tick": 1,
#     "location": "park",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-18T16:37:50.037219Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Tom Moreno, a local shop owner.\nYou occasionally visit Hobbs Cafe.\n\nIf someone tells you about an event, remember it and consider attending.\nIf you learn something interesting, mention it to others.\n\nAvailable actions: work_at_shop, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. meet Maria Lopez in the park to discuss a collaborative composition
#   2. spend 60 minutes composing new melodies for the upcoming piece
#   3. move to Hobbs Cafe to rendezvous with Isabella and Ayesha
#   4. jam session at Hobbs Cafe with Maria, Isabella, and Ayesha (improvised piece)
# ================================================================================
#
#   [AI] [Klaus Mueller] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: klaus
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "meet Maria Lopez in the park to discuss a collaborative composition",
#       "metadata": {}
#     },
#     {
#       "description": "spend 60 minutes composing new melodies for the upcoming piece",
#       "metadata": {}
#     },
#     {
#       "description": "move to Hobbs Cafe to rendezvous with Isabella and Ayesha",
#       "metadata": {}
#     },
#     {
#       "description": "jam session at Hobbs Cafe with Maria, Isabella, and Ayesha (improvised piece)",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: park
# Plan:
#   1. meet Maria Lopez in the park to discuss a collaborative composition
#   2. spend 60 minutes composing new melodies for the upcoming piece
#   3. move to Hobbs Cafe to rendezvous with Isabella and Ayesha
#   4. jam session at Hobbs Cafe with Maria, Isabella, and Ayesha (improvised piece)
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. Initiate a quick check-in with Maria Lopez at park to discuss a joint local-promotion for the shop (15 minutes)
#   2. Coordinate with Klaus Mueller at park on a shared advertising flyer and cross-promotion opportunities (15 minutes)
#   3. Move to Hobbs Cafe to catch Isabela Rodriguez for a brief coffee chat and to learn about potential cross-promotion with the cafe (20 minutes)
#   4. Return to the shop and prepare for the midday rush, restock essential items and set up a display for cross-promotions (60 minutes)
# ================================================================================
#
#   [AI] [Tom Moreno] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: tom
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Initiate a quick check-in with Maria Lopez at park to discuss a joint local-promotion for the shop (15 minutes)",
#       "metadata": {}
#     },
#     {
#       "description": "Coordinate with Klaus Mueller at park on a shared advertising flyer and cross-promotion opportunities (15 minutes)",
#       "metadata": {}
#     },
#     {
#       "description": "Move to Hobbs Cafe to catch Isabela Rodriguez for a brief coffee chat and to learn about potential cross-promotion with the cafe (20 minutes)",
#       "metadata": {}
#     },
#     {
#       "description": "Return to the shop and prepare for the midday rush, restock essential items and set up a display for cross-promotions (60 minutes)",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: park
# Plan:
#   1. Initiate a quick check-in with Maria Lopez at park to discuss a joint local-promotion for the shop (15 minutes)
#   2. Coordinate with Klaus Mueller at park on a shared advertising flyer and cross-promotion opportunities (15 minutes)
#   3. Move to Hobbs Cafe to catch Isabela Rodriguez for a brief coffee chat and to learn about potential cross-promotion with the cafe (20 minutes)
#   4. Return to the shop and prepare for the midday rush, restock essential items and set up a display for cross-promotions (60 minutes)
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 5
#   1. communicate: Invite Ayesha Khan to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   2. communicate: Invite Maria Lopez to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   3. communicate: Invite Klaus Mueller to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   4. communicate: Invite Tom Moreno to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   5. communicate: Invite Hobbs Cafe regulars and community members to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
# ================================================================================
#
#   [AI] [Isabella Rodriguez] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: isabella
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "hobbs_cafe",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "communicate: Invite Ayesha Khan to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "communicate: Invite Maria Lopez to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "communicate: Invite Klaus Mueller to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "communicate: Invite Tom Moreno to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "communicate: Invite Hobbs Cafe regulars and community members to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: hobbs_cafe
# Plan:
#   1. communicate: Invite Ayesha Khan to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   2. communicate: Invite Maria Lopez to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   3. communicate: Invite Klaus Mueller to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   4. communicate: Invite Tom Moreno to Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   5. communicate: Invite Hobbs Cafe regulars and community members to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 6
#   1. Greet Isabella at Hobbs Cafe and verify any fresh leads for a local story
#   2. Conduct a brief informal interview with cafe regulars about community concerns
#   3. Travel to nearby park to observe activity and collect quotes for follow-up questions
#   4. Return to Hobbs Cafe and compile notes into a story outline
#   5. Draft the initial local-story article emphasizing community voices
#   6. Prepare a 5–7 question follow-up list and share draft outline with Isabella for feedback
# ================================================================================
#
#   [AI] [Ayesha Khan] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: ayesha
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "hobbs_cafe",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Greet Isabella at Hobbs Cafe and verify any fresh leads for a local story",
#       "metadata": {}
#     },
#     {
#       "description": "Conduct a brief informal interview with cafe regulars about community concerns",
#       "metadata": {}
#     },
#     {
#       "description": "Travel to nearby park to observe activity and collect quotes for follow-up questions",
#       "metadata": {}
#     },
#     {
#       "description": "Return to Hobbs Cafe and compile notes into a story outline",
#       "metadata": {}
#     },
#     {
#       "description": "Draft the initial local-story article emphasizing community voices",
#       "metadata": {}
#     },
#     {
#       "description": "Prepare a 5\u20137 question follow-up list and share draft outline with Isabella for feedback",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: hobbs_cafe
# Plan:
#   1. Greet Isabella at Hobbs Cafe and verify any fresh leads for a local story
#   2. Conduct a brief informal interview with cafe regulars about community concerns
#   3. Travel to nearby park to observe activity and collect quotes for follow-up questions
#   4. Return to Hobbs Cafe and compile notes into a story outline
#   5. Draft the initial local-story article emphasizing community voices
#   6. Prepare a 5–7 question follow-up list and share draft outline with Isabella for feedback
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. Engage Klaus Mueller in the park with a friendly greeting and discuss thesis progress
#   2. Propose a short outdoor study session with Klaus for 40 minutes in a nearby bench area
#   3. Send a quick text to Isabella to arrange coffee at Hobbs Cafe after the study session
#   4. Meet Isabella at Hobbs Cafe for coffee and social time; Klaus may join later if possible
# ================================================================================
#
#   [AI] [Maria Lopez] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: maria
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Engage Klaus Mueller in the park with a friendly greeting and discuss thesis progress",
#       "metadata": {}
#     },
#     {
#       "description": "Propose a short outdoor study session with Klaus for 40 minutes in a nearby bench area",
#       "metadata": {}
#     },
#     {
#       "description": "Send a quick text to Isabella to arrange coffee at Hobbs Cafe after the study session",
#       "metadata": {}
#     },
#     {
#       "description": "Meet Isabella at Hobbs Cafe for coffee and social time; Klaus may join later if possible",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: park
# Plan:
#   1. Engage Klaus Mueller in the park with a friendly greeting and discuss thesis progress
#   2. Propose a short outdoor study session with Klaus for 40 minutes in a nearby bench area
#   3. Send a quick text to Isabella to arrange coffee at Hobbs Cafe after the study session
#   4. Meet Isabella at Hobbs Cafe for coffee and social time; Klaus may join later if possible
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: Per plan step 1: meet Maria Lopez in the park to discuss a collaborative composition; initiate direct coordination to arrange the meeting.
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria, I’m in the park and ready to discuss our collaborative composition. Shall we meet near the central fountain now, or would you prefer another...
# ================================================================================
#
#     Reasoning: Per plan step 1: meet Maria Lopez in the park to discuss a collaborative composi...
#
#     Message: "Hi Maria, I’m in the park and ready to discuss our collabora..."
#   [✓] [Klaus Mueller] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: Follow plan step 1: initiate quick check-in with Maria Lopez at park to discuss a joint local-promotion for the shop (15 minutes).
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria, can we do a quick 15-minute check-in at the park to discuss a joint local-promotion for the shop? Let me know what time works.
# ================================================================================
#
#     Reasoning: Follow plan step 1: initiate quick check-in with Maria Lopez at park to discuss ...
#
#     Message: "Hi Maria, can we do a quick 15-minute check-in at the park t..."
#   [✓] [Tom Moreno] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Ayesha Khan
# Reasoning: Execute step 1 of the plan by inviting Ayesha Khan to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
# Communication:
#   To: Ayesha Khan
#   Message: Hi Ayesha! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!
# ================================================================================
#
#     Reasoning: Execute step 1 of the plan by inviting Ayesha Khan to the Valentine's Day party ...
#
#     Message: "Hi Ayesha! I'd like to invite you to our Valentine's Day par..."
#   [✓] [Isabella Rodriguez] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Isabella
# Reasoning: Initiate Step 1 of the plan by greeting Isabella at Hobbs Cafe and prompting for any fresh leads related to a local story.
# Communication:
#   To: Isabella
#   Message: Hi Isabella, great to see you at Hobbs Cafe. Do you have any fresh leads or insights for our local story today?
# ================================================================================
#
#     Reasoning: Initiate Step 1 of the plan by greeting Isabella at Hobbs Cafe and prompting for...
#
#     Message: "Hi Isabella, great to see you at Hobbs Cafe. Do you have any..."
#   [✓] [Ayesha Khan] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Klaus Mueller
# Reasoning: Initiate engagement per plan to discuss thesis progress and establish rapport.
# Communication:
#   To: Klaus Mueller
#   Message: Hey Klaus! Great to see you. How's your thesis going? I'd love to catch up and discuss progress if you have a few minutes.
# ================================================================================
#
#     Reasoning: Initiate engagement per plan to discuss thesis progress and establish rapport....
#
#     Message: "Hey Klaus! Great to see you. How's your thesis going? I'd lo..."
#   [✓] [Maria Lopez] Got action: communicate
#   [World Engine] Processing 5 actions...
# LLM schema validation failed for WorldState (attempt 1/3).
#     - tick: Field required [type=missing] | received={'base_state': {'tick': 1, 'timestamp': '2025-10-18T16:37:50.037219Z', 'envir...
#     - timestamp: Field required [type=missing] | received={'base_state': {'tick': 1, 'timestamp': '2025-10-18T16:37:50.037219Z', 'envir...
#     - environment: Field required [type=missing] | received={'base_state': {'tick': 1, 'timestamp': '2025-10-18T16:37:50.037219Z', 'envir...
#     - resources: Field required [type=missing] | received={'base_state': {'tick': 1, 'timestamp': '2025-10-18T16:37:50.037219Z', 'envir...
#     - agents: Field required [type=missing] | received={'base_state': {'tick': 1, 'timestamp': '2025-10-18T16:37:50.037219Z', 'envir...
# LLM retry 2/3 for WorldState; attempting schema correction.
#   [World Engine] ✓ World state updated
#   [Persistence] Persisting tick 1...
#
#   [DEBUG_MEMORY] Tick 1 - Creating memories...
# ...
#     "I told Tom Moreno: Hi Tom! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!",
#     "Isabella Rodriguez invited Klaus Mueller to a Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#     "Ayesha Khan greeted Isabella Rodriguez at Hobbs Cafe and asked for fresh leads for the local story.",
#     "I communicate: Proceeding with the next plan step to invite Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#     "I told Klaus Mueller: Hi Klaus! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!",
#     "I communicate: Follow plan step 1: invite Maria Lopez to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#     "I told Maria Lopez: Hi Maria! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!",
#     "I communicate: Execute step 1 of the plan by inviting Ayesha Khan to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#     "I told Ayesha Khan: Hi Ayesha! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!"
#   ]
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "communicate: Invite Hobbs Cafe regulars and community members to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.",
#       "metadata": {
#         "target_group": "regulars and community members",
#         "date": "Feb 14",
#         "time": "5-7pm"
#       }
#     },
#     {
#       "description": "communicate: Send follow-up invitations to Tom Moreno, Klaus Mueller, Maria Lopez, and Ayesha Khan to confirm attendance.",
#       "metadata": {
#         "recipients": [
#           "Tom Moreno",
#           "Klaus Mueller",
#           "Maria Lopez",
#           "Ayesha Khan"
#         ]
#       }
#     },
#     {
#       "description": "coordinate: Track RSVP responses and update guest list from invitations sent.",
#       "metadata": {
#         "update_frequency_minutes": 60
#       }
#     },
#     {
#       "description": "promote: Post-event signage and share event details through local community channels to boost turnout.",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - [action] I communicate: Follow plan step 1 by inviting Tom Moreno to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
# - [communication] I told Tom Moreno: Hi Tom! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!
# - [observation] Isabella Rodriguez invited Klaus Mueller to a Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
# - [observation] Ayesha Khan greeted Isabella Rodriguez at Hobbs Cafe and asked for fresh leads for the local story.
# - [action] I communicate: Proceeding with the next plan step to invite Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#
# Additional context:
# Location: hobbs_cafe
# Plan:
#   1. communicate: Invite Hobbs Cafe regulars and community members to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   2. communicate: Send follow-up invitations to Tom Moreno, Klaus Mueller, Maria Lopez, and Ayesha Khan to confirm attendance.
#   3. coordinate: Track RSVP responses and update guest list from invitations sent.
#   4. promote: Post-event signage and share event details through local community channels to boost turnout.
# Recent memories:
#   - [action] I communicate: Follow plan step 1 by inviting Tom Moreno to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   - [communication] I told Tom Moreno: Hi Tom! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!
#   - [observation] Isabella Rodriguez invited Klaus Mueller to a Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#   - [observation] Ayesha Khan greeted Isabella Rodriguez at Hobbs Cafe and asked for fresh leads for the local story.
#   - [action] I communicate: Proceeding with the next plan step to invite Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm.
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: Coordinate immediate meeting for step 1 in park central fountain and confirm Maria Lopez's presence.
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria, I’m in the park near the central fountain. Shall we meet there now to discuss our collaborative composition?
# ================================================================================
#
#     Reasoning: Coordinate immediate meeting for step 1 in park central fountain and confirm Mar...
#
#     Message: "Hi Maria, I’m in the park near the central fountain. Shall w..."
#   [✓] [Klaus Mueller] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. 02:00 PM: Return to thesis work or plan next study session
#      Metadata: {'start_time': '14:00', 'duration_minutes': 0}
#   2. 02:05 PM - 02:45 PM: 40-minute outdoor study session with Klaus Mueller at park bench near central fountain to discuss thesis progress
#      Metadata: {'start_time': '14:05', 'end_time': '14:45', 'duration_minutes': 40, 'participants': ['Klaus Mueller'], 'location': 'park bench near central fountain'}
#   3. 02:45 PM - 02:50 PM: Debrief with Klaus Mueller and plan next study session
#      Metadata: {'start_time': '14:45', 'end_time': '14:50', 'duration_minutes': 5, 'participants': ['Klaus Mueller']}
#   4. 02:50 PM - 04:00 PM: Return to thesis work or plan next study session
#      Metadata: {'start_time': '14:50', 'end_time': '16:00', 'duration_minutes': 70}
# ================================================================================
#
#   [AI] [Maria Lopez] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: maria
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 5,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 14,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": [
#     "I communicate: Advance plan by confirming participation in a 40-minute outdoor study session with Klaus at a park bench to discuss thesis progress.",
#     "I told Klaus Mueller: Hi Klaus! Following our plan, would you be up for a 40-minute outdoor study session at a nearby park bench to discuss thesis progress?",
#     "Maria Lopez proposed a 40-minute outdoor study session with Klaus Mueller at a nearby park bench to discuss thesis progress.",
#     "Klaus Mueller confirmed the meeting spot near the central fountain with Maria Lopez for an immediate discussion.",
#     "Tom Moreno initiated a quick 15-minute check-in with Maria Lopez in the park to discuss a joint local-promotion for the shop.",
#     "I communicate: Follow the plan to propose a 40-minute outdoor study session with Klaus at a nearby bench area to discuss thesis progress.",
#     "I told Klaus Mueller: Klaus, as per our plan, would you be up for a 40-minute outdoor study session at a nearby bench in the park to discuss thesis progress?",
#     "I communicate: Follow the plan to greet Klaus in the park and discuss thesis progress.",
#     "I told Klaus Mueller: Hi Klaus! Great to see you. How's your thesis going? I'd love to catch up and discuss progress if you have a few minutes.",
#     "Klaus Mueller initiated a communication with Maria Lopez in the park to discuss a collaborative composition."
#   ]
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "02:00 PM: Return to thesis work or plan next study session",
#       "metadata": {
#         "start_time": "14:00",
#         "duration_minutes": 0
#       }
#     },
#     {
#       "description": "02:05 PM - 02:45 PM: 40-minute outdoor study session with Klaus Mueller at park bench near central fountain to discuss thesis progress",
#       "metadata": {
#         "start_time": "14:05",
#         "end_time": "14:45",
#         "duration_minutes": 40,
#         "participants": [
#           "Klaus Mueller"
#         ],
#         "location": "park bench near central fountain"
#       }
#     },
#     {
#       "description": "02:45 PM - 02:50 PM: Debrief with Klaus Mueller and plan next study session",
#       "metadata": {
#         "start_time": "14:45",
#         "end_time": "14:50",
#         "duration_minutes": 5,
#         "participants": [
#           "Klaus Mueller"
#         ]
#       }
#     },
#     {
#       "description": "02:50 PM - 04:00 PM: Return to thesis work or plan next study session",
#       "metadata": {
#         "start_time": "14:50",
#         "end_time": "16:00",
#         "duration_minutes": 70
#       }
#     }
#   ]
# }
#
# Recent memories:
# - [action] I communicate: Advance plan by confirming participation in a 40-minute outdoor study session with Klaus at a park bench to discuss thesis progress.
# - [communication] I told Klaus Mueller: Hi Klaus! Following our plan, would you be up for a 40-minute outdoor study session at a nearby park bench to discuss thesis progress?
# - [observation] Maria Lopez proposed a 40-minute outdoor study session with Klaus Mueller at a nearby park bench to discuss thesis progress.
# - [observation] Klaus Mueller confirmed the meeting spot near the central fountain with Maria Lopez for an immediate discussion.
# - [observation] Tom Moreno initiated a quick 15-minute check-in with Maria Lopez in the park to discuss a joint local-promotion for the shop.
#
# Additional context:
# Location: park
# Plan:
#   1. 02:00 PM: Return to thesis work or plan next study session
#   2. 02:05 PM - 02:45 PM: 40-minute outdoor study session with Klaus Mueller at park bench near central fountain to discuss thesis progress
#   3. 02:45 PM - 02:50 PM: Debrief with Klaus Mueller and plan next study session
#   4. 02:50 PM - 04:00 PM: Return to thesis work or plan next study session
# Recent memories:
#   - [action] I communicate: Advance plan by confirming participation in a 40-minute outdoor study session with Klaus at a park bench to discuss thesis progress.
#   - [communication] I told Klaus Mueller: Hi Klaus! Following our plan, would you be up for a 40-minute outdoor study session at a nearby park bench to discuss thesis progress?
#   - [observation] Maria Lopez proposed a 40-minute outdoor study session with Klaus Mueller at a nearby park bench to discuss thesis progress.
#   - [observation] Klaus Mueller confirmed the meeting spot near the central fountain with Maria Lopez for an immediate discussion.
#   - [observation] Tom Moreno initiated a quick 15-minute check-in with Maria Lopez in the park to discuss a joint local-promotion for the shop.
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: hobbs_cafe
# Parameters: {'focus': 'conduct informal interviews with cafe regulars to identify community concerns and collect quotes for follow-up questions'}
# Reasoning: Follows Plan Step 1: conduct informal interviews with cafe regulars to identify community concerns and collect quotes for follow-up questions
# ================================================================================
#
#     Reasoning: Follows Plan Step 1: conduct informal interviews with cafe regulars to identify ...
#   [✓] [Ayesha Khan] Got action: work
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: To advance Plan Step 1 by arranging a quick 15-minute park check-in with Maria Lopez to discuss a joint local-promotion for the shop.
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria, can we do a quick 15-minute check-in at the park today to discuss a joint local-promotion for the shop? What time works?
# ================================================================================
#
#     Reasoning: To advance Plan Step 1 by arranging a quick 15-minute park check-in with Maria L...
#
#     Message: "Hi Maria, can we do a quick 15-minute check-in at the park t..."
#   [✓] [Tom Moreno] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Klaus Mueller
# Reasoning: Following the plan, initiate the 40-minute outdoor study session with Klaus Mueller at the park bench near the central fountain to discuss thesis progress; Klaus has confirmed the meeting location, ti...
# Communication:
#   To: Klaus Mueller
#   Message: Hi Klaus! As per our plan, the 40-minute outdoor study session is starting now at the park bench near the central fountain to discuss thesis progress....
# ================================================================================
#
#     Reasoning: Following the plan, initiate the 40-minute outdoor study session with Klaus Muel...
#
#     Message: "Hi Klaus! As per our plan, the 40-minute outdoor study sessi..."
#   [✓] [Maria Lopez] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Klaus Mueller
# Reasoning: Continue executing Plan Step 1 by inviting Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm as part of inviting regulars and community members.
# Communication:
#   To: Klaus Mueller
#   Message: Hi Klaus! I'd like to invite you to our Valentine's Day party at Hobbs Cafe on Feb 14th, 5-7pm. Hope you can join us!
# ================================================================================
#
#     Reasoning: Continue executing Plan Step 1 by inviting Klaus Mueller to the Valentine's Day ...
#
#     Message: "Hi Klaus! I'd like to invite you to our Valentine's Day part..."
#   [✓] [Isabella Rodriguez] Got action: communicate
#   [World Engine] Processing 5 actions...

# %% [markdown]
# ## Step 9: Analyze Information Diffusion
#
# Let's see how many agents learned about the party!

# %%
run_id = result['run_id']

print('=== INFORMATION DIFFUSION ANALYSIS ===')
print('\n📢 Party Awareness Test:')
print('   Checking which agents know about the Valentine\'s party...\n')

for agent_id, profile in agents.items():
    # Query agent's memory for party-related content
    memories = await memory.get_relevant_memories(
        run_id,
        agent_id,
        query="Valentine's Day party Hobbs Cafe February 14",
        limit=3
    )
    
    knows_about_party = any('party' in m.lower() or 'valentine' in m.lower() for m in memories)
    status = '✅' if knows_about_party else '❌'
    
    print(f'{status} {profile.name}:')
    if knows_about_party:
        print(f'   Knows about party! Relevant memory:')
        party_mem = next(m for m in memories if 'party' in m.lower() or 'valentine' in m.lower())
        preview = party_mem[:100] + '...' if len(party_mem) > 100 else party_mem
        print(f'   "{preview}"')
    else:
        print(f'   No party memories found')
    print()

# Count who knows - must await each call separately
aware_agents = []
for agent_id in agents.keys():
    memories = await memory.get_relevant_memories(run_id, agent_id, "party", 3)
    if any('party' in m.lower() for m in memories):
        aware_agents.append(agent_id)
aware_count = len(aware_agents)

print(f'\n📊 Result: {aware_count}/{len(agents)} agents aware of the party')
print(f'   Stanford paper: 13/25 agents (52%)')
print(f'   Our simulation: {aware_count}/{len(agents)} agents ({aware_count/len(agents)*100:.0f}%)')

if aware_count > 0:
    print(f'\n   Aware agents: {", ".join([agents[aid].name for aid in aware_agents])}')
# Out:
# === INFORMATION DIFFUSION ANALYSIS ===
#
# 📢 Party Awareness Test:
#    Checking which agents know about the Valentine's party...
#
# ❌ Isabella Rodriguez:
#    No party memories found
#
# ❌ Maria Lopez:
#    No party memories found
#
# ❌ Klaus Mueller:
#    No party memories found
#
# ❌ Ayesha Khan:
#    No party memories found
#
# ❌ Tom Moreno:
#    No party memories found
#
#
# 📊 Result: 0/5 agents aware of the party
#    Stanford paper: 13/25 agents (52%)
#    Our simulation: 0/5 agents (0%)

# %% [markdown]
# ## Step 10: Check Who Showed Up
#
# Did agents independently decide to go to Hobbs Cafe at the right time?

# %%
final_state = result['final_state']

print('=== PARTY ATTENDANCE ===')
print('\n🎉 Final locations (Feb 14, 5pm):\n')

attendees = []
for agent in final_state.agents:
    profile = agents[agent.agent_id]
    at_party = agent.location == 'hobbs_cafe'
    status = '🎉' if at_party else '  '
    
    print(f'{status} {profile.name}: {agent.location}')
    if at_party:
        attendees.append(profile.name)

print(f'\n📊 Attendance: {len(attendees)}/{len(agents)} agents at Hobbs Cafe')
print(f'   Stanford paper: 5/12 invited showed up (42%)')
print(f'   Our simulation: {len(attendees)}/{len(agents)} showed up ({len(attendees)/len(agents)*100:.0f}%)')

if attendees:
    print(f'\n   Party guests: {", ".join(attendees)}')
# Out:
# === PARTY ATTENDANCE ===
#
# 🎉 Final locations (Feb 14, 5pm):
#
# 🎉 Isabella Rodriguez: hobbs_cafe
#    Maria Lopez: park
#    Klaus Mueller: park
# 🎉 Ayesha Khan: hobbs_cafe
#    Tom Moreno: park
#
# 📊 Attendance: 2/5 agents at Hobbs Cafe
#    Stanford paper: 5/12 invited showed up (42%)
#    Our simulation: 2/5 showed up (40%)
#
#    Party guests: Isabella Rodriguez, Ayesha Khan

# %% [markdown]
# ## 💡 What Just Happened?
#
# ### Emergent Coordination
#
# 1. **Seed**: Isabella initialized with party goal
# 2. **Spread**: Isabella invited people → they remembered
# 3. **Retrieval**: When planning, agents retrieved party memory using embeddings
# 4. **Decision**: Agents independently chose to attend
# 5. **Coordination**: Multiple agents arrived at same place/time
#
# **No hardcoded teamwork!** Just:
# - Memory (with embedding-based retrieval)
# - Planning (LLM decides based on memories)
# - Dialogue (agents tell each other)
#
# ### Key Implementation Detail: Custom Memory Adapter
#
# ```python
# # We defined EmbeddingMemoryStream in THIS NOTEBOOK
# memory = EmbeddingMemoryStream(persistence)
#
# # Then plugged it into orchestrator
# orchestrator = Orchestrator(..., memory=memory)
# ```
#
# **This demonstrates Miniverse's adapter pattern!** You can:
# - Use built-in `SimpleMemoryStream` (keyword matching)
# - Use built-in `ImportanceWeightedMemory` (recency + importance)
# - Create custom strategy (like we did here!)
# - Swap strategies without changing other code
#
# ### Limitations vs Stanford
#
# ⚠️ **Scale**: 5 agents vs Stanford's 25
# ⚠️ **Environment**: Flat locations vs hierarchical tree
# ⚠️ **Duration**: 8 ticks vs 2 full days
# ⚠️ **Interactions**: Simplified vs Stanford's full spatial movement
#
# **But the core mechanism works!** Information diffuses, agents remember, coordination emerges.
#
# ---
#
# ## 🚀 Next Steps
#
# Want to extend this?
#
# 1. **Add more agents** - Scale up to 25 like Stanford
# 2. **Add locations** - Library, park, shops
# 3. **Add relationships** - Maria invites Klaus as her date
# 4. **Add reactions** - Agents respond to unexpected events
# 5. **Compare retrieval strategies** - Run with `SimpleMemoryStream` vs `EmbeddingMemoryStream`
#
# The framework is ready - just extend the scenario!
#
# ---
#
# **Paper reference**: Park et al. (2023). "Generative Agents: Interactive Simulacra of Human Behavior." https://arxiv.org/abs/2304.03442
