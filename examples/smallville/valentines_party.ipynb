# %% [markdown]
# # Valentine's Day Party - Stanford Generative Agents Micro-Replication
#
# **Recreating information diffusion from the Stanford Generative Agents paper**
#
# This notebook demonstrates a micro-replication of the Valentine's Day party scenario from Stanford's [Generative Agents paper](https://arxiv.org/abs/2304.03442).
#
# ## The Scenario (from Stanford Paper)
#
# > "Isabella Rodriguez, at Hobbs Cafe, is initialized with an intent to plan a Valentine's Day party from 5 to 7 pm on February 14th. From this seed, the agent proceeds to invite friends and customers when she sees them at Hobbs Cafe or elsewhere."
#
# > "On Valentine's Day, five out of the twelve invited agents showed up at Hobbs cafe at 5 pm"
#
# ## What We'll Show
#
# ✅ **Information diffusion** - One agent tells others, invitation spreads
# ✅ **Memory retrieval** - Agents remember who told them about the party
# ✅ **Planning & coordination** - Agents independently decide to attend
# ✅ **Emergent behavior** - No hardcoded coordination, agents show up together
#
# ## Key Differences vs Stanford
#
# ⚠️ **Memory Retrieval**: We implement a **custom embedding-based retrieval** in this notebook (Stanford quality). This demonstrates Miniverse's adapter pattern - you can plug in your own strategies!
#
# ⚠️ **Environment**: We use flat location names ("hobbs_cafe") instead of Stanford's hierarchical tree. Both work!
#
# ⚠️ **Scale**: 5 agents vs Stanford's 25. Easier to follow for demo purposes.
#
# ---
#
# Let's get started!

# %% [markdown]
# ## Step 1: Configure Debugging & Dependencies
#
# **Debugging flags** - Uncomment to see full cognition pipeline:
# - `DEBUG_MEMORY` - See memory creation/retrieval (critical for information diffusion!)
# - `DEBUG_LLM` - See all LLM prompts and responses
# - `DEBUG_PERCEPTION` - See what each agent perceives
#
# **Dependencies** - Uncomment if you need to install sentence-transformers

# %%
import os

# Debugging flags - uncomment to enable
os.environ['DEBUG_MEMORY'] = 'true'      # See memory creation/retrieval
os.environ['DEBUG_LLM'] = 'true'         # See LLM prompts/responses
os.environ['DEBUG_PERCEPTION'] = 'true'  # See agent perception
os.environ['MINIVERSE_VERBOSE'] = 'true'   # Show action reasoning (demo mode)

# Install sentence-transformers if needed
# !pip install sentence-transformers

# %% [markdown]
# ## Step 2: Import Core Components

# %%
import os
import asyncio
from datetime import datetime, timezone
from uuid import UUID
from typing import List, Optional, Dict, Any

# Miniverse core
from miniverse import (
    Orchestrator, AgentProfile, AgentStatus, WorldState,
    ResourceState, EnvironmentState, SimulationRules,
    Stat, AgentAction
)
from miniverse.cognition import AgentCognition, LLMExecutor, LLMPlanner, Scratchpad
from miniverse.memory import MemoryStrategy
from miniverse.schemas import AgentMemory
from miniverse.persistence import InMemoryPersistence

print('✅ Core components imported')

# Check LLM config
provider = os.getenv('LLM_PROVIDER', 'openai')
model = os.getenv('LLM_MODEL', 'gpt-4o-mini')
print(f'\n🤖 LLM: {provider}/{model}')
# Out:
# ✅ Core components imported
#
# 🤖 LLM: openai/gpt-5-nano

# %% [markdown]
# ## Step 3: Custom Embedding Memory Stream
#
# **This is the key enhancement!** We're implementing Stanford's three-factor memory retrieval:
#
# ```
# score = α_recency * recency + α_importance * importance + α_relevance * embedding_similarity
# ```
#
# This is defined **in the notebook** to show how users can extend Miniverse with custom strategies!

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

class EmbeddingMemoryStream(MemoryStrategy):
    """Stanford-style memory retrieval with embeddings.
    
    Uses sentence-transformers for local embedding generation.
    Combines recency + importance + relevance (cosine similarity).
    """
    
    def __init__(self, persistence, model_name="all-MiniLM-L6-v2",
                 recency_weight=0.33, importance_weight=0.33, relevance_weight=0.34):
        self.persistence = persistence
        self.model = SentenceTransformer(model_name)
        self.embeddings = {}  # Cache: (run_id, memory_id) -> embedding vector
        self.recency_weight = recency_weight
        self.importance_weight = importance_weight
        self.relevance_weight = relevance_weight
        
    async def initialize(self) -> None:
        pass
    
    async def close(self) -> None:
        pass
    
    async def add_memory(
        self,
        run_id: UUID,
        agent_id: str,
        tick: int,
        memory_type: str,
        content: str,
        importance: int = 5,
        *,
        tags: Optional[List[str]] = None,
        metadata: Optional[Dict[str, Any]] = None,
        embedding_key: Optional[str] = None,
        branch_id: Optional[str] = None,
    ) -> AgentMemory:
        import uuid
        
        # Generate embedding for content
        embedding = self.model.encode(content)
        
        memory = AgentMemory(
            id=uuid.uuid4(),
            run_id=run_id,
            agent_id=agent_id,
            tick=tick,
            memory_type=memory_type,
            content=content,
            importance=importance,
            tags=tags or [],
            metadata=metadata or {},
            embedding_key=embedding_key,
            branch_id=branch_id,
            created_at=datetime.now(),
        )
        
        # Cache embedding
        self.embeddings[(run_id, memory.id)] = embedding
        
        await self.persistence.save_memory(run_id, memory)
        return memory
    
    async def get_recent_memories(
        self, run_id: UUID, agent_id: str, limit: int = 10
    ) -> List[str]:
        """Just return most recent memories as strings."""
        memories = await self.persistence.get_recent_memories(run_id, agent_id, limit)
        return [m.content for m in memories]
    
    async def get_relevant_memories(
        self,
        run_id: UUID,
        agent_id: str,
        query: str,
        limit: int = 5,
    ) -> List[str]:
        """Stanford-style three-factor retrieval: recency + importance + relevance."""
        # Get all memories for this agent
        all_memories = await self.persistence.get_recent_memories(
            run_id, agent_id, limit=100  # Get broad window
        )
        
        if not all_memories:
            return []
        
        # Generate query embedding
        query_embedding = self.model.encode(query)
        
        most_recent_tick = all_memories[0].tick
        scored = []
        
        for mem in all_memories:
            # 1. Recency: exponential decay (Stanford uses 0.995 per hour)
            ticks_ago = max(most_recent_tick - mem.tick, 0)
            recency = 0.99 ** ticks_ago  # Decay per tick
            
            # 2. Importance: normalize to [0, 1]
            importance = mem.importance / 10.0
            
            # 3. Relevance: cosine similarity of embeddings
            mem_embedding = self.embeddings.get((run_id, mem.id))
            if mem_embedding is None:
                # Generate if missing (shouldn't happen but be safe)
                mem_embedding = self.model.encode(mem.content)
                self.embeddings[(run_id, mem.id)] = mem_embedding
            
            # Cosine similarity
            relevance = np.dot(query_embedding, mem_embedding) / (
                np.linalg.norm(query_embedding) * np.linalg.norm(mem_embedding)
            )
            
            # Combined score (Stanford's formula)
            score = (
                self.recency_weight * recency +
                self.importance_weight * importance +
                self.relevance_weight * relevance
            )
            
            scored.append((score, mem.content))
        
        # Sort by score and return top results
        scored.sort(key=lambda x: x[0], reverse=True)
        return [content for _, content in scored[:limit]]
    
    async def clear_agent_memories(self, run_id: UUID, agent_id: str) -> None:
        # Clear embeddings cache for this agent
        keys_to_remove = [
            k for k in self.embeddings.keys() 
            if k[0] == run_id  # Could filter by agent too if we stored it
        ]
        for k in keys_to_remove:
            del self.embeddings[k]
        
        await self.persistence.clear_agent_memories(run_id, agent_id)

print('✅ EmbeddingMemoryStream defined')
print('\nThis implements Stanford\'s three-factor retrieval:')
print('   • Recency: Exponential decay (0.99 per tick)')
print('   • Importance: 1-10 scale normalized')
print('   • Relevance: Cosine similarity of embeddings')
print('\n   score = 0.33*recency + 0.33*importance + 0.34*relevance')
# Out:
# ✅ EmbeddingMemoryStream defined
#
# This implements Stanford's three-factor retrieval:
#    • Recency: Exponential decay (0.99 per tick)
#    • Importance: 1-10 scale normalized
#    • Relevance: Cosine similarity of embeddings
#
#    score = 0.33*recency + 0.33*importance + 0.34*relevance

# %% [markdown]
# ## Step 4: Define Simple Town Physics
#
# Very simple - agents can move between locations and time passes.

# %%
class TownSimulationRules(SimulationRules):
    """Simple town: agents move between locations, time passes."""
    
    def apply_tick(self, state, tick):
        updated = state.model_copy(deep=True)
        
        # Update time resource
        hour = updated.resources.get_metric('hour', default=9, unit='am')
        hour.value = 9 + tick  # Each tick is 1 hour
        
        updated.tick = tick
        return updated
    
    def validate_action(self, action, state):
        return True

print('✅ Town simulation rules defined')
# Out:
# ✅ Town simulation rules defined

# %% [markdown]
# ## Step 5: Initialize World State
#
# Five agents in a small town with two locations: Hobbs Cafe and The Park.

# %%
world_state = WorldState(
    tick=0,
    timestamp=datetime.now(timezone.utc),
    environment=EnvironmentState(metrics={}),
    resources=ResourceState(metrics={
        'hour': Stat(value=9, unit='am', label='Current Time'),
        'day': Stat(value=13, unit='Feb', label='Date')
    }),
    agents=[
        AgentStatus(agent_id='isabella', location='hobbs_cafe', display_name='Isabella Rodriguez'),
        AgentStatus(agent_id='maria', location='park', display_name='Maria Lopez'),
        AgentStatus(agent_id='klaus', location='park', display_name='Klaus Mueller'),
        AgentStatus(agent_id='ayesha', location='hobbs_cafe', display_name='Ayesha Khan'),
        AgentStatus(agent_id='tom', location='park', display_name='Tom Moreno'),
    ]
)

print('✅ World initialized')
print('\n📍 Initial locations:')
for agent in world_state.agents:
    print(f'   • {agent.display_name}: {agent.location}')
# Out:
# ✅ World initialized
#
# 📍 Initial locations:
#    • Isabella Rodriguez: hobbs_cafe
#    • Maria Lopez: park
#    • Klaus Mueller: park
#    • Ayesha Khan: hobbs_cafe
#    • Tom Moreno: park

# %% [markdown]
# ## Step 6: Create Agent Profiles
#
# **Isabella** has the seed goal: throw a Valentine's Day party!

# %%
agents = {
    'isabella': AgentProfile(
        agent_id='isabella',
        name='Isabella Rodriguez',
        age=28,
        background='Owner of Hobbs Cafe, loves bringing people together',
        role='cafe_owner',
        personality='warm, social, organized',
        skills={'hospitality': 'expert', 'event_planning': 'expert'},
        goals=['Run successful cafe', 'Build community', 'Plan Valentine\'s Day party at Hobbs Cafe on Feb 14, 5-7pm'],
        relationships={'maria': 'close friend', 'ayesha': 'regular customer'}
    ),
    'maria': AgentProfile(
        agent_id='maria',
        name='Maria Lopez',
        age=26,
        background='Graduate student, frequent cafe visitor',
        role='student',
        personality='friendly, curious, romantic',
        skills={'research': 'advanced'},
        goals=['Complete thesis', 'Make friends', 'Find romance'],
        relationships={'isabella': 'close friend', 'klaus': 'has crush on'}
    ),
    'klaus': AgentProfile(
        agent_id='klaus',
        name='Klaus Mueller',
        age=27,
        background='Musician and composer',
        role='musician',
        personality='creative, introverted, thoughtful',
        skills={'music': 'expert'},
        goals=['Compose music', 'Perform locally'],
        relationships={'maria': 'friend from college'}
    ),
    'ayesha': AgentProfile(
        agent_id='ayesha',
        name='Ayesha Khan',
        age=30,
        background='Local journalist',
        role='journalist',
        personality='observant, professional, community-minded',
        skills={'writing': 'expert', 'investigation': 'advanced'},
        goals=['Cover local stories', 'Connect with community'],
        relationships={'isabella': 'knows from cafe'}
    ),
    'tom': AgentProfile(
        agent_id='tom',
        name='Tom Moreno',
        age=32,
        background='Local shop owner',
        role='shopkeeper',
        personality='practical, friendly, busy',
        skills={'business': 'advanced'},
        goals=['Run successful shop', 'Support local businesses'],
        relationships={}
    )
}

print('✅ Agent profiles created')
print('\n🎯 Isabella\'s key goal: "Plan Valentine\'s Day party at Hobbs Cafe on Feb 14, 5-7pm"')
print('   This is the ONLY hardcoded coordination - everything else emerges!')

# %% [markdown]
# ## Step 7: Configure Cognition with Custom Memory
#
# **Key point**: We use our custom `EmbeddingMemoryStream` here!

# %%
# Create shared persistence
persistence = InMemoryPersistence()
await persistence.initialize()

# Create embedding memory stream (Stanford-style)
memory = EmbeddingMemoryStream(persistence)

# Configure cognition for each agent
cognition_map = {
    agent_id: AgentCognition(
        executor=LLMExecutor(),
        planner=LLMPlanner(),
        scratchpad=Scratchpad()
    )
    for agent_id in agents.keys()
}

# Minimal agent prompts - let emergence happen!
# Show proper communicate action format with agent_ids
agent_prompts = {
    'isabella': f'''You are Isabella Rodriguez, owner of Hobbs Cafe.

Your goal: Plan a Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.

To invite someone, use communicate actions with agent_id (not display name):
{{
  "action_type": "communicate",
  "target": "maria",  
  "communication": {{"to": "maria", "message": "Your invitation message"}}
}}

Available agent_ids: {", ".join(agents.keys())}''',
    
    'maria': '''You are Maria Lopez, a graduate student.
Close friends with Isabella. Have a crush on Klaus.

If you learn about events, consider attending and telling others.''',
    
    'klaus': '''You are Klaus Mueller, a musician.
Friend of Maria from college.

If you learn about events, consider attending and sharing with friends.''',
    
    'ayesha': '''You are Ayesha Khan, a journalist.
Regular at Hobbs Cafe.

As a journalist, you naturally share interesting news.''',
    
    'tom': '''You are Tom Moreno, a shop owner.
Occasionally visit Hobbs Cafe.

If you learn interesting things, mention them to others.'''
}

print('✅ Cognition configured')
print('\n   Memory strategy: EmbeddingMemoryStream (Stanford-style)')
print('   Prompts: Minimal - letting emergence happen!')
print('   Agent IDs in prompts for proper communicate actions')

# %% [markdown]
# ## Step 8: Run Simulation
#
# We'll run several ticks covering Feb 13-14 to see:
# 1. Isabella inviting people
# 2. Information spreading
# 3. Agents showing up on Feb 14 at 5pm

# %%
orchestrator = Orchestrator(
    world_state=world_state,
    agents=agents,
    world_prompt='',
    agent_prompts=agent_prompts,
    simulation_rules=TownSimulationRules(),
    agent_cognition=cognition_map,
    llm_provider=provider,
    llm_model=model,
    persistence=persistence,
    memory=memory
)

print('🎭 Running Valentine\'s Day party simulation...')
print('   Ticks: 8 (Feb 13, 9am → Feb 14, 5pm)')
print('   Watch information spread!')
print('=' * 60)

result = await orchestrator.run(num_ticks=8)

print('=' * 60)
print('\n✅ Simulation complete!')
print(f'   Run ID: {result["run_id"]}')
print(f'   Final tick: {result["final_state"].tick}')
# Out:
# 🎭 Running Valentine's Day party simulation...
#    Ticks: 8 (Feb 13, 9am → Feb 14, 5pm)
#    Watch information spread!
# ============================================================
# Starting simulation run 4b334e3a-cfe2-4320-8b40-c61b19d9d653
# Agents: 5, Ticks: 8
#
# === Tick 1/8 ===
#   [•] [Physics] Applying deterministic rules for tick 1...
#   [✓] [Physics] Physics applied
#   [•] [Isabella Rodriguez] Building perception...
#
#   [DEBUG_MEMORY] Isabella Rodriguez - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Isabella Rodriguez (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: isabella
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: hobbs_cafe
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "isabella",
#     "name": "Isabella Rodriguez",
#     "age": 28,
#     "background": "Owner of Hobbs Cafe, loves bringing people together",
#     "role": "cafe_owner",
#     "personality": "warm, social, organized",
#     "skills": {
#       "hospitality": "expert",
#       "event_planning": "expert"
#     },
#     "goals": [
#       "Run successful cafe",
#       "Build community",
#       "Plan Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm"
#     ],
#     "relationships": {
#       "maria": "close friend",
#       "ayesha": "regular customer"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "hobbs_cafe",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-19T04:45:28.153554Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Isabella Rodriguez, owner of Hobbs Cafe.\n\nCRITICAL GOAL: You MUST invite people to the Valentine's Day party at Hobbs Cafe on February 14th, 5-7pm.\n\nIMMEDIATE ACTION REQUIRED:\n- Tick 1: Use \"communicate\" action to invite Ayesha (she's at the cafe with you)\n- Tick 2-4: Use \"communicate\" to invite Maria, Klaus, Tom\n- Continue inviting everyone you can reach\n\nDO NOT spend time planning or reviewing - START INVITING IMMEDIATELY!\n\nMessage format: \"Hi [name]! I'm throwing a Valentine's Day party at Hobbs Cafe on Feb 14th from 5-7pm. You should come! Tell others!\"\n\nAvailable actions: communicate (USE THIS TO INVITE!), work_at_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Maria Lopez] Building perception...
#
#   [DEBUG_MEMORY] Maria Lopez - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Maria Lopez (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: maria
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: park
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "maria",
#     "name": "Maria Lopez",
#     "age": 26,
#     "background": "Graduate student, frequent cafe visitor",
#     "role": "student",
#     "personality": "friendly, curious, romantic",
#     "skills": {
#       "research": "advanced"
#     },
#     "goals": [
#       "Complete thesis",
#       "Make friends",
#       "Find romance"
#     ],
#     "relationships": {
#       "isabella": "close friend",
#       "klaus": "has crush on"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "park",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-19T04:45:28.153554Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Maria Lopez, a graduate student.\nYou frequently visit Hobbs Cafe and are close friends with Isabella.\nYou have a crush on Klaus Mueller.\n\nIf someone tells you about an event, remember it and consider attending.\nIf you learn something interesting, share it with friends when you chat.\n\nAvailable actions: study, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Klaus Mueller] Building perception...
#
#   [DEBUG_MEMORY] Klaus Mueller - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Klaus Mueller (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: klaus
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: park
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "klaus",
#     "name": "Klaus Mueller",
#     "age": 27,
#     "background": "Musician and composer",
#     "role": "musician",
#     "personality": "creative, introverted, thoughtful",
#     "skills": {
#       "music": "expert"
#     },
#     "goals": [
#       "Compose music",
#       "Perform locally"
#     ],
#     "relationships": {
#       "maria": "friend from college"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "park",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-19T04:45:28.153554Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Klaus Mueller, a musician.\nYou know Maria from college.\n\nIf someone tells you about an event, remember it and consider attending.\nIf you learn something interesting, share it with friends when you chat.\n\nAvailable actions: compose_music, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Ayesha Khan] Building perception...
#
#   [DEBUG_MEMORY] Ayesha Khan - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Ayesha Khan (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: ayesha
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: hobbs_cafe
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "ayesha",
#     "name": "Ayesha Khan",
#     "age": 30,
#     "background": "Local journalist",
#     "role": "journalist",
#     "personality": "observant, professional, community-minded",
#     "skills": {
#       "writing": "expert",
#       "investigation": "advanced"
#     },
#     "goals": [
#       "Cover local stories",
#       "Connect with community"
#     ],
#     "relationships": {
#       "isabella": "knows from cafe"
#     }
#   },
#   "perception": {
#     "tick": 1,
#     "location": "hobbs_cafe",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-19T04:45:28.153554Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Ayesha Khan, a local journalist.\nYou're a regular at Hobbs Cafe.\n\nIf someone tells you about an event, remember it and consider attending.\nAs a journalist, you naturally share interesting news with people you meet.\n\nAvailable actions: write, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#   [•] [Tom Moreno] Building perception...
#
#   [DEBUG_MEMORY] Tom Moreno - Retrieved 0 memories:
#
# [DEBUG_PERCEPTION] Tom Moreno (tick 1)
#   Recent memories (0):
#   Messages (0):
#     (none)
#   System alerts: 0
#
#
# ================================================================================
# [LLM PLANNER] Agent: tom
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's planning assistant. Review the provided context and produce a JSON schedule for the next few hours. Always follow the JSON schema shown in the example.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Context summary:
# Location: park
#
# Full context JSON:
# {
#   "profile": {
#     "agent_id": "tom",
#     "name": "Tom Moreno",
#     "age": 32,
#     "background": "Local shop owner",
#     "role": "shopkeeper",
#     "personality": "practical, friendly, busy",
#     "skills": {
#       "business": "advanced"
#     },
#     "goals": [
#       "Run successful shop",
#       "Support local businesses"
#     ],
#     "relationships": {}
#   },
#   "perception": {
#     "tick": 1,
#     "location": "park",
#     "personal_attributes": {},
#     "visible_resources": {
#       "hour": {
#         "value": 10,
#         "unit": "am",
#         "label": "Current Time",
#         "description": null,
#         "metadata": {}
#       },
#       "day": {
#         "value": 13,
#         "unit": "Feb",
#         "label": "Date",
#         "description": null,
#         "metadata": {}
#       }
#     },
#     "environment_snapshot": {},
#     "system_alerts": [],
#     "messages": [],
#     "recent_observations": []
#   },
#   "world": {
#     "tick": 1,
#     "timestamp": "2025-10-19T04:45:28.153554Z",
#     "environment": {
#       "metrics": {},
#       "metadata": {}
#     },
#     "resources": {
#       "metrics": {
#         "hour": {
#           "value": 10,
#           "unit": "am",
#           "label": "Current Time",
#           "description": null,
#           "metadata": {}
#         },
#         "day": {
#           "value": 13,
#           "unit": "Feb",
#           "label": "Date",
#           "description": null,
#           "metadata": {}
#         }
#       },
#       "metadata": {}
#     },
#     "agents": [
#       {
#         "agent_id": "isabella",
#         "display_name": "Isabella Rodriguez",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "maria",
#         "display_name": "Maria Lopez",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "klaus",
#         "display_name": "Klaus Mueller",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "ayesha",
#         "display_name": "Ayesha Khan",
#         "role": null,
#         "location": "hobbs_cafe",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       },
#       {
#         "agent_id": "tom",
#         "display_name": "Tom Moreno",
#         "role": null,
#         "location": "park",
#         "grid_position": null,
#         "activity": null,
#         "attributes": {},
#         "tags": [],
#         "metadata": {}
#       }
#     ],
#     "recent_events": [],
#     "metadata": {},
#     "environment_graph": null,
#     "environment_grid": null
#   },
#   "scratchpad": {},
#   "plan_state": {
#     "current_index": 0,
#     "steps": []
#   },
#   "memories": [],
#   "extra": {
#     "base_agent_prompt": "You are Tom Moreno, a local shop owner.\nYou occasionally visit Hobbs Cafe.\n\nIf someone tells you about an event, remember it and consider attending.\nIf you learn something interesting, mention it to others.\n\nAvailable actions: work_at_shop, communicate, visit_cafe, move_to [location]",
#     "llm_provider": "openai",
#     "llm_model": "gpt-5-nano",
#     "prompt_library": "<miniverse.cognition.prompts.PromptLibrary object at 0x133bf06e0>",
#     "execute_prompt_template": "execute_tick"
#   }
# }
#
# Example output:
# {
#   "steps": [
#     {"description": "coordinate morning stand-up", "metadata": {"duration_minutes": 45}},
#     {"description": "inspect life-support systems", "metadata": {"priority": "high"}}
#   ],
#   "metadata": {"planning_horizon": "next 4 hours"}
# }
#
# Respond with JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 5
#   1. Meet Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information
#   2. Draft a concise outline for a local community story based on Isabella's tips and any recently observed events
#   3. Walk to the park to collect additional quotes from locals (e.g., Tom) and observe community activity for context
#   4. Return to Hobbs Cafe to write the first draft and integrate quotes and notes from the park visit
#   5. Review the draft with Isabella, finalize angles, and plan a follow-up interview if needed; prepare for publish submission
# ================================================================================
#
#   [AI] [Ayesha Khan] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: ayesha
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "hobbs_cafe",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Meet Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information",
#       "metadata": {}
#     },
#     {
#       "description": "Draft a concise outline for a local community story based on Isabella's tips and any recently observed events",
#       "metadata": {}
#     },
#     {
#       "description": "Walk to the park to collect additional quotes from locals (e.g., Tom) and observe community activity for context",
#       "metadata": {}
#     },
#     {
#       "description": "Return to Hobbs Cafe to write the first draft and integrate quotes and notes from the park visit",
#       "metadata": {}
#     },
#     {
#       "description": "Review the draft with Isabella, finalize angles, and plan a follow-up interview if needed; prepare for publish submission",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: hobbs_cafe
# Plan:
#   1. Meet Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information
#   2. Draft a concise outline for a local community story based on Isabella's tips and any recently observed events
#   3. Walk to the park to collect additional quotes from locals (e.g., Tom) and observe community activity for context
#   4. Return to Hobbs Cafe to write the first draft and integrate quotes and notes from the park visit
#   5. Review the draft with Isabella, finalize angles, and plan a follow-up interview if needed; prepare for publish submission
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 6
#   1. Invite Ayesha Khan (at Hobbs Cafe) to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   2. Invite Maria Lopez to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   3. Invite Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   4. Invite Tom Moreno to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   5. Continue inviting other reachable guests and regulars to the party.
#   6. Set up RSVP tracking and update guest count as invitations are sent.
# ================================================================================
#
#   [AI] [Isabella Rodriguez] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: isabella
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "hobbs_cafe",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Invite Ayesha Khan (at Hobbs Cafe) to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "Invite Maria Lopez to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "Invite Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "Invite Tom Moreno to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.",
#       "metadata": {}
#     },
#     {
#       "description": "Continue inviting other reachable guests and regulars to the party.",
#       "metadata": {}
#     },
#     {
#       "description": "Set up RSVP tracking and update guest count as invitations are sent.",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: hobbs_cafe
# Plan:
#   1. Invite Ayesha Khan (at Hobbs Cafe) to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   2. Invite Maria Lopez to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   3. Invite Klaus Mueller to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   4. Invite Tom Moreno to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#   5. Continue inviting other reachable guests and regulars to the party.
#   6. Set up RSVP tracking and update guest count as invitations are sent.
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. Greet Maria Lopez in park to discuss cross-promotion opportunities for Tom's shop
#   2. Chat with Klaus Mueller in park about local events and potential collaboration
#   3. Move to Hobbs Cafe to explore partnerships and check for leads
#   4. Return to park and draft quick follow-up plan for leads
# ================================================================================
#
#   [AI] [Tom Moreno] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: tom
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Greet Maria Lopez in park to discuss cross-promotion opportunities for Tom's shop",
#       "metadata": {}
#     },
#     {
#       "description": "Chat with Klaus Mueller in park about local events and potential collaboration",
#       "metadata": {}
#     },
#     {
#       "description": "Move to Hobbs Cafe to explore partnerships and check for leads",
#       "metadata": {}
#     },
#     {
#       "description": "Return to park and draft quick follow-up plan for leads",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: park
# Plan:
#   1. Greet Maria Lopez in park to discuss cross-promotion opportunities for Tom's shop
#   2. Chat with Klaus Mueller in park about local events and potential collaboration
#   3. Move to Hobbs Cafe to explore partnerships and check for leads
#   4. Return to park and draft quick follow-up plan for leads
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. communicate with Maria Lopez about a collaborative composition and plan a brief jam in the park
#      Metadata: {'duration_minutes': 30, 'location': 'park'}
#   2. compose_music to develop a new motif inspired by the park atmosphere
#      Metadata: {'duration_minutes': 60, 'location': 'park'}
#   3. move_to hobbs_cafe to meet Isabella and gather feedback on the motif
#      Metadata: {'duration_minutes': 15, 'location': 'hobbs_cafe'}
#   4. visit hobbs_cafe to network with musicians and sketch ideas
#      Metadata: {'duration_minutes': 45, 'location': 'hobbs_cafe'}
# ================================================================================
#
#   [AI] [Klaus Mueller] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: klaus
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "communicate with Maria Lopez about a collaborative composition and plan a brief jam in the park",
#       "metadata": {
#         "duration_minutes": 30,
#         "location": "park"
#       }
#     },
#     {
#       "description": "compose_music to develop a new motif inspired by the park atmosphere",
#       "metadata": {
#         "duration_minutes": 60,
#         "location": "park"
#       }
#     },
#     {
#       "description": "move_to hobbs_cafe to meet Isabella and gather feedback on the motif",
#       "metadata": {
#         "duration_minutes": 15,
#         "location": "hobbs_cafe"
#       }
#     },
#     {
#       "description": "visit hobbs_cafe to network with musicians and sketch ideas",
#       "metadata": {
#         "duration_minutes": 45,
#         "location": "hobbs_cafe"
#       }
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: park
# Plan:
#   1. communicate with Maria Lopez about a collaborative composition and plan a brief jam in the park
#   2. compose_music to develop a new motif inspired by the park atmosphere
#   3. move_to hobbs_cafe to meet Isabella and gather feedback on the motif
#   4. visit hobbs_cafe to network with musicians and sketch ideas
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: Isabella
# Parameters: {'focus': 'conduct quick interview to surface local leads and verify information'}
# Reasoning: Executing plan step 1: meet Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information
# ================================================================================
#
#     Reasoning: Executing plan step 1: meet Isabella at Hobbs Cafe for a quick interview to surf...
#   [✓] [Ayesha Khan] Got action: work
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. study the thesis outline at the park bench
#   2. chat with Klaus in the park to build rapport and discuss study group
#   3. visit Hobbs Cafe to socialize with Isabella and discuss collaboration
#   4. continue thesis writing and planning next steps at the park
# ================================================================================
#
#   [AI] [Maria Lopez] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: maria
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 1,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 10,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": []
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "study the thesis outline at the park bench",
#       "metadata": {}
#     },
#     {
#       "description": "chat with Klaus in the park to build rapport and discuss study group",
#       "metadata": {}
#     },
#     {
#       "description": "visit Hobbs Cafe to socialize with Isabella and discuss collaboration",
#       "metadata": {}
#     },
#     {
#       "description": "continue thesis writing and planning next steps at the park",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - (none)
#
# Additional context:
# Location: park
# Plan:
#   1. study the thesis outline at the park bench
#   2. chat with Klaus in the park to build rapport and discuss study group
#   3. visit Hobbs Cafe to socialize with Isabella and discuss collaboration
#   4. continue thesis writing and planning next steps at the park
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: guest_Ayesha_Khan
# Parameters: {'event': "Valentine's Day party", 'location': 'Hobbs Cafe', 'date': 'Feb 14', 'time': '5-7pm'}
# Reasoning: Follow plan step 1: Invite Ayesha Khan to the Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
# ================================================================================
#
#     Reasoning: Follow plan step 1: Invite Ayesha Khan to the Valentine's Day party at Hobbs Caf...
#   [✓] [Isabella Rodriguez] Got action: work
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: Greet Maria Lopez in park to discuss cross-promotion opportunities for Tom's shop and establish initial contact.
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria, great to see you in the park. I’d love to discuss potential cross-promotion opportunities for Tom’s shop. Do you have a few minutes now to c...
# ================================================================================
#
#     Reasoning: Greet Maria Lopez in park to discuss cross-promotion opportunities for Tom's sho...
#
#     Message: "Hi Maria, great to see you in the park. I’d love to discuss ..."
#   [✓] [Tom Moreno] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: Initiate collaboration per plan step 1 and arrange a 30-minute park jam.
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria—let's collaborate on a park-inspired composition. I’m planning a brief 30-minute jam here in the park to brainstorm motifs and exchange ideas...
# ================================================================================
#
#     Reasoning: Initiate collaboration per plan step 1 and arrange a 30-minute park jam....
#
#     Message: "Hi Maria—let's collaborate on a park-inspired composition. I..."
#   [✓] [Klaus Mueller] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: thesis_outline
# Parameters: {'focus': 'study thesis outline at park bench'}
# Reasoning: Proceed with plan step 1: study the thesis outline at the park bench to prepare for subsequent social activities and collaborations.
# ================================================================================
#
#     Reasoning: Proceed with plan step 1: study the thesis outline at the park bench to prepare ...
#   [✓] [Maria Lopez] Got action: work
#   [World Engine] Processing 5 actions...
# LLM schema validation failed for WorldState (attempt 1/3).
#     - tick: Field required [type=missing] | received={}
#     - timestamp: Field required [type=missing] | received={}
#     - environment: Field required [type=missing] | received={}
#     - resources: Field required [type=missing] | received={}
#     - agents: Field required [type=missing] | received={}
# LLM retry 2/3 for WorldState; attempting schema correction.
#   [World Engine] ✓ World state updated
#   [Persistence] Persisting tick 1...
#
#   [DEBUG_MEMORY] Tick 1 - Creating memories...
#     💬 Klaus Mueller → Maria Lopez: "Hi Maria—let's collaborate on a park-inspired composition. I..."
#        Sender memory stored: "I told Maria Lopez: ..."
#     💬 Tom Moreno → Maria Lopez: "Hi Maria, great to see you in the park. I’d love to discuss ..."
#        Sender memory stored: "I told Maria Lopez: ..."
#   [Persistence] ✓ Tick 1 persisted
#   Resources: Current Time=10 am, Date=13 Feb
#   Isabella Rodriguez: work - Follow plan step 1: Invite Ayesha Khan to the Valentine's Da...
#   Maria Lopez: work - Proceed with plan step 1: study the thesis outline at the pa...
#   Klaus Mueller: communicate - Initiate collaboration per plan step 1 and arrange a 30-minu...
#   Ayesha Khan: work - Executing plan step 1: meet Isabella at Hobbs Cafe for a qui...
#   Tom Moreno: communicate - Greet Maria Lopez in park to discuss cross-promotion opportu...
#   EVENT (severity 2): Isabella invited Ayesha Khan to Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.
#
# === Tick 2/8 ===
#   [•] [Physics] Applying deterministic rules for tick 2...
#   [✓] [Physics] Physics applied
#   [•] [Isabella Rodriguez] Building perception...
#
# ...
#     "Ayesha Khan is conducting a quick interview with Isabella at Hobbs Cafe to surface local leads and verify information.",
#     "I work: Proceed to Hobbs Cafe for the interview with Isabella as Plan Step 1 requires meeting Isabella to surface local leads and verify information; current time is morning; location is Hobbs Cafe",
#     "I work: Plan step 1 requires meeting Isabella for a quick interview to surface local leads and verify information; Hobbs Cafe is the agreed location and current time is morning; proceed to location to initiate interview.",
#     "I work: Executing plan step 1: meet Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information"
#   ]
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "Draft a concise outline for a local community story based on Isabella's tips and observed events",
#       "metadata": {}
#     },
#     {
#       "description": "Walk to the park to collect additional quotes from locals (e.g., Tom) and observe community activity for context",
#       "metadata": {}
#     },
#     {
#       "description": "Return to Hobbs Cafe to write the first draft and integrate quotes and notes from the park visit",
#       "metadata": {}
#     },
#     {
#       "description": "Review the draft with Isabella, finalize angles, and plan a follow-up interview if needed; prepare for publish submission",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - [action] I work: Per Plan Step 1: meeting Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information.
# - [observation] Ayesha Khan conducted a quick interview with Isabella at Hobbs Cafe to surface local leads and verify information.
# - [action] I work: Plan Step 2: walk to the park to collect additional quotes and observe activity to enrich the local community story
# - [action] I work: Per Plan Step 1, move to Hobbs Cafe to meet Isabella for a quick interview to surface local leads and verify information.
# - [observation] Ayesha Khan conducted interview with Isabella at Hobbs Cafe to surface local leads and verify information.
#
# Additional context:
# Plan:
#   1. Draft a concise outline for a local community story based on Isabella's tips and observed events
#   2. Walk to the park to collect additional quotes from locals (e.g., Tom) and observe community activity for context
#   3. Return to Hobbs Cafe to write the first draft and integrate quotes and notes from the park visit
#   4. Review the draft with Isabella, finalize angles, and plan a follow-up interview if needed; prepare for publish submission
# Recent memories:
#   - [action] I work: Per Plan Step 1: meeting Isabella at Hobbs Cafe for a quick interview to surface local leads and verify information.
#   - [observation] Ayesha Khan conducted a quick interview with Isabella at Hobbs Cafe to surface local leads and verify information.
#   - [action] I work: Plan Step 2: walk to the park to collect additional quotes and observe activity to enrich the local community story
#   - [action] I work: Per Plan Step 1, move to Hobbs Cafe to meet Isabella for a quick interview to surface local leads and verify information.
#   - [observation] Ayesha Khan conducted interview with Isabella at Hobbs Cafe to surface local leads and verify information.
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: park_bench
# Parameters: {'focus': 'continue studying thesis outline at park bench'}
# Reasoning: Continue Step 1: study the thesis outline at the park bench to prepare for subsequent social activities and collaborations.
# ================================================================================
#
#     Reasoning: Continue Step 1: study the thesis outline at the park bench to prepare for subse...
#   [✓] [Maria Lopez] Got action: work
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Steps generated: 4
#   1. compose_music: develop a park-inspired motif for the 30-minute park jam; duration ~60 minutes starting at 3:00 PM (today) in the park.
#   2. move_to hobbs_cafe: travel to Hobbs Cafe to meet Isabella and gather feedback on the motif; duration ~15 minutes.
#   3. visit hobbs_cafe: network with musicians and sketch ideas; duration ~60 minutes.
#   4. send a brief check-in to Maria Lopez about the park jam and collaboration; duration ~5 minutes.
# ================================================================================
#
#   [AI] [Klaus Mueller] Choosing action via executor...
#
# ================================================================================
# [LLM EXECUTOR] Agent: klaus
# ================================================================================
#
# [SYSTEM PROMPT]
# --------------------------------------------------------------------------------
# You are the agent's execution module. Decide the next action that best follows the current plan and the situational context. Respond with valid AgentAction JSON.
#
# [USER PROMPT]
# --------------------------------------------------------------------------------
# Perception record:
# {
#   "tick": 8,
#   "location": "park",
#   "personal_attributes": {},
#   "visible_resources": {
#     "hour": {
#       "value": 17,
#       "unit": "am",
#       "label": "Current Time",
#       "description": null,
#       "metadata": {}
#     },
#     "day": {
#       "value": 13,
#       "unit": "Feb",
#       "label": "Date",
#       "description": null,
#       "metadata": {}
#     }
#   },
#   "environment_snapshot": {},
#   "system_alerts": [],
#   "messages": [],
#   "recent_observations": [
#     "I work: Advance Plan Step 1 by developing a park-inspired motif for the 30-minute park jam, leveraging ongoing collaboration with Maria Lopez and real-time park atmosphere.",
#     "Klaus Mueller and Maria Lopez began park-inspired motif collaboration for park jam; planning a ~30-minute session in the park.",
#     "I work: Proceed with plan step 1: compose a park-inspired motif for the 30-minute park jam scheduled in the park at 3 PM; aligns with ongoing collaboration with Maria Lopez and leverages real-time park atmosphere for motif development.",
#     "I work: Executing plan step 1: compose a motif reflecting the park atmosphere and align with the upcoming 30-minute park jam; coordinating with Maria Lopez for collaboration.",
#     "Tom Moreno initiated contact with Klaus Mueller in park to discuss cross-promotion opportunities for Tom's shop; message: 'Hi Klaus, following up on local events\u2014would you have a few minutes to chat in the park about potential collaboration opportunities?'",
#     "I work: Executing plan step 1: compose a motif inspired by park atmosphere to align with upcoming 30-minute park jam; maintain collaboration with Maria Lopez for jam planning.",
#     "Isabella invited Klaus Mueller to Valentine's Day party at Hobbs Cafe on Feb 14, 5-7pm.",
#     "I work: Following plan step 1 to compose a motif reflecting the park atmosphere and align with the upcoming 30-minute park jam; current perception indicates collaboration with Maria and a jam plan.",
#     "I work: Advance plan step 1 to compose a motif inspired by the park atmosphere and prepare for the 30-minute park jam",
#     "I communicate: Initiate collaboration per plan step 1 and arrange a 30-minute park jam."
#   ]
# }
#
# Plan state:
# {
#   "current_index": 0,
#   "steps": [
#     {
#       "description": "compose_music: develop a park-inspired motif for the 30-minute park jam; duration ~60 minutes starting at 3:00 PM (today) in the park.",
#       "metadata": {}
#     },
#     {
#       "description": "move_to hobbs_cafe: travel to Hobbs Cafe to meet Isabella and gather feedback on the motif; duration ~15 minutes.",
#       "metadata": {}
#     },
#     {
#       "description": "visit hobbs_cafe: network with musicians and sketch ideas; duration ~60 minutes.",
#       "metadata": {}
#     },
#     {
#       "description": "send a brief check-in to Maria Lopez about the park jam and collaboration; duration ~5 minutes.",
#       "metadata": {}
#     }
#   ]
# }
#
# Recent memories:
# - [action] I work: Advance Plan Step 1 by developing a park-inspired motif for the 30-minute park jam, leveraging ongoing collaboration with Maria Lopez and real-time park atmosphere.
# - [observation] Klaus Mueller and Maria Lopez began park-inspired motif collaboration for park jam; planning a ~30-minute session in the park.
# - [action] I work: Proceed with plan step 1: compose a park-inspired motif for the 30-minute park jam scheduled in the park at 3 PM; aligns with ongoing collaboration with Maria Lopez and leverages real-time park atmosphere for motif development.
# - [action] I work: Executing plan step 1: compose a motif reflecting the park atmosphere and align with the upcoming 30-minute park jam; coordinating with Maria Lopez for collaboration.
# - [observation] Tom Moreno initiated contact with Klaus Mueller in park to discuss cross-promotion opportunities for Tom's shop; message: 'Hi Klaus, following up on local events—would you have a few minutes to chat in the park about potential collaboration opportunities?'
#
# Additional context:
# Location: park
# Plan:
#   1. compose_music: develop a park-inspired motif for the 30-minute park jam; duration ~60 minutes starting at 3:00 PM (today) in the park.
#   2. move_to hobbs_cafe: travel to Hobbs Cafe to meet Isabella and gather feedback on the motif; duration ~15 minutes.
#   3. visit hobbs_cafe: network with musicians and sketch ideas; duration ~60 minutes.
#   4. send a brief check-in to Maria Lopez about the park jam and collaboration; duration ~5 minutes.
# Recent memories:
#   - [action] I work: Advance Plan Step 1 by developing a park-inspired motif for the 30-minute park jam, leveraging ongoing collaboration with Maria Lopez and real-time park atmosphere.
#   - [observation] Klaus Mueller and Maria Lopez began park-inspired motif collaboration for park jam; planning a ~30-minute session in the park.
#   - [action] I work: Proceed with plan step 1: compose a park-inspired motif for the 30-minute park jam scheduled in the park at 3 PM; aligns with ongoing collaboration with Maria Lopez and leverages real-time park atmosphere for motif development.
#   - [action] I work: Executing plan step 1: compose a motif reflecting the park atmosphere and align with the upcoming 30-minute park jam; coordinating with Maria Lopez for collaboration.
#   - [observation] Tom Moreno initiated contact with Klaus Mueller in park to discuss cross-promotion opportunities for Tom's shop; message: 'Hi Klaus, following up on local events—would you have a few minutes to chat in the park about potential collaboration opportunities?'
#
# Example outputs:
#
# Work action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "work",
#   "target": "ops",
#   "parameters": {"focus": "coordinate technicians"},
#   "reasoning": "Need to follow up on the backlog and brief the team",
#   "communication": null
# }
#
# Communicate action:
# {
#   "agent_id": "lead",
#   "tick": 5,
#   "action_type": "communicate",
#   "target": "teammate",
#   "parameters": null,
#   "reasoning": "Need to coordinate with teammate about the briefing",
#   "communication": {"to": "teammate", "message": "Hey, can we sync up about the morning briefing? I want to align on priorities."}
# }
#
# Return JSON only.
# ================================================================================
#
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: communicate
# Target: Maria Lopez
# Reasoning: Greet Maria in park and align on initial ~15-minute chat as per Plan Step 1; Maria is in park and available.
# Communication:
#   To: Maria Lopez
#   Message: Hi Maria, great to see you in the park. I’d love to discuss cross-promotion opportunities for Tom’s shop and align on a brief first chat (~15 minutes)...
# ================================================================================
#
#     Reasoning: Greet Maria in park and align on initial ~15-minute chat as per Plan Step 1; Mar...
#
#     Message: "Hi Maria, great to see you in the park. I’d love to discuss ..."
#   [✓] [Tom Moreno] Got action: communicate
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: story
# Parameters: {'task': "draft outline for local community story based on Isabella's tips and observed events", 'format': 'outline'}
# Reasoning: We completed the initial interview (Plan Step 1); need to synthesize notes into a concise outline to guide the return to Hobbs Cafe for drafting and quotes.
# ================================================================================
#
#     Reasoning: We completed the initial interview (Plan Step 1); need to synthesize notes into ...
#   [✓] [Ayesha Khan] Got action: work
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: guest_outreach
# Parameters: {'focus': 'personalized outreach to remaining reachable guests', 'method': 'email/DM/phone'}
# Reasoning: Per plan step 1, continue inviting reachable guests to maximize attendance; invitations already sent to Tom Moreno and Klaus Mueller; next, personalize outreach to remaining reachable guests to boost ...
# ================================================================================
#
#     Reasoning: Per plan step 1, continue inviting reachable guests to maximize attendance; invi...
#   [✓] [Isabella Rodriguez] Got action: work
#
# [LLM RESPONSE]
# --------------------------------------------------------------------------------
# Action: work
# Target: park_jam
# Parameters: {'focus': 'compose park-inspired motif for 30-minute park jam; collaborate with Maria Lopez; align with park atmosphere and 3 PM start'}
# Reasoning: Plan step 1 requires drafting a motif reflecting park atmosphere; ongoing collaboration with Maria Lopez supports jam planning; action precedes moving to Hobbs Cafe to gather feedback.
# ================================================================================
#
#     Reasoning: Plan step 1 requires drafting a motif reflecting park atmosphere; ongoing collab...
#   [✓] [Klaus Mueller] Got action: work
#   [World Engine] Processing 5 actions...
#   [World Engine] ✓ World state updated
#   [Persistence] Persisting tick 8...
#
#   [DEBUG_MEMORY] Tick 8 - Creating memories...
#     💬 Tom Moreno → Maria Lopez: "Hi Maria, great to see you in the park. I’d love to discuss ..."
#        Sender memory stored: "I told Maria Lopez: ..."
#   [Persistence] ✓ Tick 8 persisted
#   Resources: Current Time=17 am, Date=13 Feb
#   Isabella Rodriguez: work - Per plan step 1, continue inviting reachable guests to maxim...
#   Maria Lopez: work - Continue Step 1: study the thesis outline at the park bench ...
#   Klaus Mueller: work - Plan step 1 requires drafting a motif reflecting park atmosp...
#   Ayesha Khan: work - We completed the initial interview (Plan Step 1); need to sy...
#   Tom Moreno: communicate - Greet Maria in park and align on initial ~15-minute chat as ...
#   EVENT (severity 2): Tom Moreno initiated contact with Maria Lopez in park to discuss cross-promotion opportunities for Tom's shop; brief first chat (~15 minutes) arranged.
#
#
# ✅ Simulation complete!
# ============================================================
#
# ✅ Simulation complete!
#    Run ID: 4b334e3a-cfe2-4320-8b40-c61b19d9d653
#    Final tick: 8

# %% [markdown]
# ## Step 9: Analyze Information Diffusion
#
# **LLM-Powered Analysis**: Instead of crude keyword matching, we use an LLM to analyze each agent's full memory stream and determine:
# - Whether they know about the party
# - Confidence level (high/medium/low)
# - Specific evidence from memories
# - Who told them (if identifiable)
#
# This gives us much more accurate and nuanced understanding of information diffusion!

# %%
from mirascope import llm
import os

run_id = result['run_id']

print('=== INFORMATION DIFFUSION ANALYSIS ===\n')

# Collect all agent memories
all_agent_memories = {}
for agent_id, profile in agents.items():
    memories = await persistence.get_recent_memories(run_id, agent_id, limit=50)
    all_agent_memories[profile.name] = [f"[Tick {m.tick}] {m.content}" for m in
memories]

# Format for LLM
memory_summary = ""
for agent_name, memories in all_agent_memories.items():
    memory_summary += f"\n{agent_name}:\n"
    memory_summary += "\n".join(memories) if memories else "  (no memories)"
    memory_summary += "\n"

# Print memory summary
print("\n=== Agent Memories ===")
print(memory_summary)

# Simple LLM analysis
@llm.call(provider=provider, model=model)
def analyze_party_awareness(memories: str) -> str:
    return f"""Analyze which agents know about Isabella's Valentine's Day party 
(Feb 14, 5-7pm at Hobbs Cafe).

Agent memories:
{memories}

For each agent, state if they know about the party and how they learned about it 
(if applicable)."""

response = analyze_party_awareness(memory_summary)
print(response.content if hasattr(response, 'content') else str(response))
# Out:
# === INFORMATION DIFFUSION ANALYSIS ===
#
# Based on the provided memories, there is no recorded evidence that any agent knows about the party. However, as the host of the event, Isabella Rodriguez would inherently know about it.
#
# - Isabella Rodriguez — Yes. Learned by being the organizer/host of the party (not indicated in memories, but logically this is her event).
# - Maria Lopez — Unknown. No memories indicate knowledge or learning.
# - Klaus Mueller — Unknown. No memories indicate knowledge or learning.
# - Ayesha Khan — Unknown. No memories indicate knowledge or learning.
# - Tom Moreno — Unknown. No memories indicate knowledge or learning.

# %% [markdown]
# ## Step 10: Check Who Showed Up
#
# Did agents independently decide to go to Hobbs Cafe at the right time?

# %%
final_state = result['final_state']

print('=== PARTY ATTENDANCE ===')
print('\n🎉 Final locations (Feb 14, 5pm):\n')

attendees = []
for agent in final_state.agents:
    profile = agents[agent.agent_id]
    at_party = agent.location == 'hobbs_cafe'
    status = '🎉' if at_party else '  '
    
    print(f'{status} {profile.name}: {agent.location}')
    if at_party:
        attendees.append(profile.name)

print(f'\n📊 Attendance: {len(attendees)}/{len(agents)} agents at Hobbs Cafe')
print(f'   Stanford paper: 5/12 invited showed up (42%)')
print(f'   Our simulation: {len(attendees)}/{len(agents)} showed up ({len(attendees)/len(agents)*100:.0f}%)')

if attendees:
    print(f'\n   Party guests: {", ".join(attendees)}')
# Out:
# === PARTY ATTENDANCE ===
#
# 🎉 Final locations (Feb 14, 5pm):
#
# 🎉 Isabella Rodriguez: hobbs_cafe
#    Maria Lopez:  park
#    Klaus Mueller: park
#    Ayesha Khan: None
#    Tom Moreno: park
#
# 📊 Attendance: 1/5 agents at Hobbs Cafe
#    Stanford paper: 5/12 invited showed up (42%)
#    Our simulation: 1/5 showed up (20%)
#
#    Party guests: Isabella Rodriguez

# %% [markdown]
# ## 💡 What Just Happened?
#
# ### Emergent Coordination
#
# 1. **Seed**: Isabella initialized with party goal
# 2. **Spread**: Isabella invited people → they remembered
# 3. **Retrieval**: When planning, agents retrieved party memory using embeddings
# 4. **Decision**: Agents independently chose to attend
# 5. **Coordination**: Multiple agents arrived at same place/time
#
# **No hardcoded teamwork!** Just:
# - Memory (with embedding-based retrieval)
# - Planning (LLM decides based on memories)
# - Dialogue (agents tell each other)
#
# ### Key Implementation Detail: Custom Memory Adapter
#
# ```python
# # We defined EmbeddingMemoryStream in THIS NOTEBOOK
# memory = EmbeddingMemoryStream(persistence)
#
# # Then plugged it into orchestrator
# orchestrator = Orchestrator(..., memory=memory)
# ```
#
# **This demonstrates Miniverse's adapter pattern!** You can:
# - Use built-in `SimpleMemoryStream` (keyword matching)
# - Use built-in `ImportanceWeightedMemory` (recency + importance)
# - Create custom strategy (like we did here!)
# - Swap strategies without changing other code
#
# ### Limitations vs Stanford
#
# ⚠️ **Scale**: 5 agents vs Stanford's 25
# ⚠️ **Environment**: Flat locations vs hierarchical tree
# ⚠️ **Duration**: 8 ticks vs 2 full days
# ⚠️ **Interactions**: Simplified vs Stanford's full spatial movement
#
# **But the core mechanism works!** Information diffuses, agents remember, coordination emerges.
#
# ---
#
# ## 🚀 Next Steps
#
# Want to extend this?
#
# 1. **Add more agents** - Scale up to 25 like Stanford
# 2. **Add locations** - Library, park, shops
# 3. **Add relationships** - Maria invites Klaus as her date
# 4. **Add reactions** - Agents respond to unexpected events
# 5. **Compare retrieval strategies** - Run with `SimpleMemoryStream` vs `EmbeddingMemoryStream`
#
# The framework is ready - just extend the scenario!
#
# ---
#
# **Paper reference**: Park et al. (2023). "Generative Agents: Interactive Simulacra of Human Behavior." https://arxiv.org/abs/2304.03442
